# %% [markdown]
# #   РАЗВЕДЫВАТЕЛЬНЫЙ АНАЛИЗ ДАННЫХ
# ### PROJECT: EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ### Цель:
# Отследить влияние условий жизни учащихся в возрасте от 15 до 22 лет на их успеваемость по математике, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.

# %% [markdown]
# ### Структура:
# 1. Импорт и вспомогательные функции
# 2. Первичный осмотр данных
# 3. Анализ категориальных и числовых переменных
# 4. Корреляционный анализ
# 5. Анализ номинативных переменных
# 6. Выводы

# %% [markdown]
# # 1. Импорт данных и вспомогательные функции

# %%
# Импортируем необходимые библиотеки и установим количество отображаемых строк и столбцов по умолчанию
import pandas as pd
import numpy as np
from itertools import combinations
 
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import ttest_ind, norm
from statsmodels.stats.multicomp import (pairwise_tukeyhsd, MultiComparison)
import statsmodels.formula.api as sm 

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 100)      # показывать больше строк
pd.set_option('display.max_columns', 50)    # показывать больше столбцов
plt.rcParams['figure.figsize'] = (4.5, 3.5)

# %%
def column_info(DF, col):
    # Функция для вывода информации о колонке
    # DF - датафрейм, col - имя колонки 
    display(pd.DataFrame(DF[col].value_counts()))
    print('\nУникальных значений:', DF[col].nunique())
    if len(DF[col].unique()) < 30:
        print(f'Уникальные значения: {DF[col].unique()}')
    else:
        print(f'Некоторые уникальные значения: {DF[col].unique()[:30]}')
    if DF[col].isna().sum() != 0:
        print(f'Пропущенных значений: {DF[col].isna().sum()} из {len(DF[col])}, что составляет: {round(100 * DF[col].isna().sum() / len(DF[col]), 2)}%\n')
    else:
        print(f'Пропущенных значений: {DF[col].isna().sum()}\n')
    display(DF[col].info())

# %%
def outliers_z_score(ys, threshold = 3):
    # Функция для определения выбросов 
    # Поиск по отклонению (z-score)
    mean_y = np.mean(ys)
    std_y = np.std(ys)
    z_scores =  [(y - mean_y) / std_y for y in ys]
    return np.where(np.abs(z_scores) > threshold)[0]

# %%
def outliers_iqr(ys):
    # Функция для определения выбросов 
    # Формула межквартильного расстояния 
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])   # vis_data.distance.quantile([0.25, 0.75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    return np.where((ys > upper_bound) | (ys < lower_bound))[0]

# %%
def estimate_gaussian(dataset):
    # Функция для определения выбросов 
    # Поиск по распределению
    mu = np.mean(dataset, axis = 0)
    sigma = np.cov(dataset.T)
    return mu, sigma

def get_gaussian(mu, sigma):
    distribution = norm(mu, sigma)
    return distribution

def get_probs(distribution, dataset):
    return distribution.pdf(dataset)

# %%
def get_distplot(df, x, bins = 20):
    # Функция для потроения дистплота
    ax = sns.distplot(df, x = df[x], bins = 20)
    ax.set_title(x)

# %%
def get_boxplot(DF, column, parameter):
    # функция для быстрого построения боксплотов
    fig, ax = plt.subplots(figsize = (8, 4))
    sns.boxplot(
                x = column, y = parameter,
                data = DF.loc[DF.loc[:, column].isin(DF.loc[:, column].value_counts().index[:10])],
                ax = ax, flierprops = {"marker" : "x"}, medianprops = {"color" : "coral"},
                 )
    plt.xticks(rotation = 90)
    ax.set_title('Boxplot for ' + column)
    plt.show()

# %%
def BruteForce(params: set, formula: str, result: set) -> str:
    # Функция для нахождения набора переменных, обеспечивающих максимальный R-squared
    if not params:
        result.add(formula.lstrip('+ '))
        return
    else:
        new_params = params.copy()
        for el in params:
            new_params.remove(el)
            BruteForce(new_params, formula + ' + ' + el, result)
            BruteForce(new_params, formula, result)

# %%
def stat_dif_bonf(DF, column, parameter):
    # Функция для множественного сравнения в классическом варианте дисперсионного анализа (ANOVA)
    cols = DF.loc[:, column].value_counts().index[:10]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(DF.loc[DF.loc[:, column] == comb[0], parameter],
                     DF.loc[DF.loc[:, column] == comb[1], parameter]).pvalue \
                <= 0.05 / len(combinations_all):  # Учли поправку Бонферони
            print(f'- Найдены статистически значимые различия для переменной "{column}": {comb[1]}, {comb[0]}.')
            # break

# %%
def stat_dif_tukey(DataFrame, columns_in, columns_predict, most_popular_num, alpha):
    # Критерий Тьюки для множественных сравнений ANOVA (однофакторного дисперсионного анализа)
    result = pd.DataFrame()     # Итоговый датафрейм
    for col in columns_in:
        df = DataFrame.loc[DataFrame.loc[:, col].isin(
            DataFrame.loc[:, col].value_counts().index[:most_popular_num])]
        df = df[[columns_predict, col]]
        df = df.dropna()     # Избавимся от выбросов, т.к. statsmodels не может работать с пустыми значениями

        MultiComp = MultiComparison(df[columns_predict], df[col])
        MC = pd.DataFrame(MultiComp.tukeyhsd(alpha).summary())
        MC = MC.loc[1:]

        MC.columns = ['group1', 'group2', 'meandiff',
                      'p-adj', 'lower', 'upper', 'reject']
        MC.group1 = MC.group1.astype('str')
        MC.group2 = MC.group2.astype('str')
        MC.meandiff = MC.meandiff.astype('str')
        MC.meandiff = MC.meandiff.astype('float64')
        MC['p-adj'] = MC['p-adj'].astype('str')
        MC['p-adj'] = MC['p-adj'].astype('float64')
        MC['lower'] = MC['lower'].astype('str')
        MC['lower'] = MC['lower'].astype('float64')
        MC['upper'] = MC['upper'].astype('str')
        MC['upper'] = MC['upper'].astype('float64')
        MC['reject'] = MC['reject'].astype('str')
        MC[MC.reject == 'True']
        MC.reject = MC.reject.apply(lambda x: True if x == 'True' else False)
        MC['feature'] = col     # Признак, по которому найдено различие в группах
        result = result.append(MC)
    display(result[result.reject == True])
    print(f"Найдены статистически значимые различия в: \n{result[result.reject == True].feature.value_counts()}")

# %% [markdown]
# # 2. Первичный осмотр данных

# %%
# Загрузим данные и посмотрим на датасет
df = pd.read_csv('math_study.csv')
display(df)
display(df.info())
print(f"Размер датасета: {df.shape}\n")
print(f'\nКоличество уникальных значений: \n{df.nunique()}')
print('\nКоличество пропущенных значений:')
for col in df.columns:
    if df[col].isna().sum() > 0:
        print(col, ':', df[col].isna().sum())
display(df.describe())
display(df.describe(include = 'object'))
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1       GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2       GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4       GP   F   16       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
# 391     MS   M   17       U     LE3       T   3.0   1.0  services  services
# 392     MS   M   21       R     GT3       T   1.0   1.0     other     other
# 393     MS   M   18       R     LE3       T   3.0   2.0  services     other
# 394     MS   M   19       U     LE3       T   1.0   1.0     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother         2.0        2.0       0.0       yes     no   no
# 1    course   father         1.0        2.0       0.0        no    yes   no
# 2     other   mother         1.0        2.0       3.0       yes     no  NaN
# 3      home   mother         1.0        3.0       0.0        no    yes  yes
# 4      home   father         1.0        2.0       0.0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 390  course      NaN         1.0        2.0       2.0        no    yes  yes
# 391  course   mother         2.0        1.0       0.0        no     no   no
# 392  course      NaN         1.0        1.0       3.0       NaN     no   no
# 393  course   mother         3.0        1.0       0.0        no     no   no
# 394     NaN   father         1.0        1.0       0.0       NaN     no   no
#
#     activities nursery  studytime, granular higher internet romantic  famrel  \
# 0           no     yes                 -6.0    yes      NaN       no     4.0
# 1           no      no                 -6.0    yes      yes       no     5.0
# 2           no     yes                 -6.0    yes      yes      NaN     4.0
# 3          yes     yes                 -9.0    yes      yes      yes     3.0
# 4           no     yes                 -6.0    yes       no       no     4.0
# ..         ...     ...                  ...    ...      ...      ...     ...
# 390         no     yes                 -6.0    yes       no       no     5.0
# 391         no      no                 -3.0    yes      yes       no     2.0
# 392         no      no                 -3.0    NaN       no       no     5.0
# 393        NaN      no                 -3.0    yes      yes       no     4.0
# 394         no     yes                 -3.0    yes      yes       no     3.0
#
#      freetime  goout  health  absences  score
# 0         3.0    4.0     3.0       6.0   30.0
# 1         3.0    3.0     3.0       4.0   30.0
# 2         3.0    2.0     3.0      10.0   50.0
# 3         2.0    2.0     5.0       2.0   75.0
# 4         3.0    2.0     5.0       4.0   50.0
# ..        ...    ...     ...       ...    ...
# 390       5.0    4.0     4.0     212.0   45.0
# 391       4.0    5.0     2.0       3.0   80.0
# 392       5.0    3.0     3.0       3.0   35.0
# 393       4.0    1.0     5.0       0.0   50.0
# 394       2.0    3.0     5.0       5.0   45.0
#
# [395 rows x 30 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   school               395 non-null    object
#  1   sex                  395 non-null    object
#  2   age                  395 non-null    int64
#  3   address              378 non-null    object
#  4   famsize              368 non-null    object
#  5   Pstatus              350 non-null    object
#  6   Medu                 392 non-null    float64
#  7   Fedu                 371 non-null    float64
#  8   Mjob                 376 non-null    object
#  9   Fjob                 359 non-null    object
#  10  reason               378 non-null    object
#  11  guardian             364 non-null    object
#  12  traveltime           367 non-null    float64
#  13  studytime            388 non-null    float64
#  14  failures             373 non-null    float64
#  15  schoolsup            386 non-null    object
#  16  famsup               356 non-null    object
#  17  paid                 355 non-null    object
#  18  activities           381 non-null    object
#  19  nursery              379 non-null    object
#  20  studytime, granular  388 non-null    float64
#  21  higher               375 non-null    object
#  22  internet             361 non-null    object
#  23  romantic             364 non-null    object
#  24  famrel               368 non-null    float64
#  25  freetime             384 non-null    float64
#  26  goout                387 non-null    float64
#  27  health               380 non-null    float64
#  28  absences             383 non-null    float64
#  29  score                389 non-null    float64
# dtypes: float64(12), int64(1), object(17)
# memory usage: 92.7+ KB
# None
# Размер датасета: (395, 30)
#
#
# Количество уникальных значений:
# school                  2
# sex                     2
# age                     8
# address                 2
# famsize                 2
# Pstatus                 2
# Medu                    5
# Fedu                    6
# Mjob                    5
# Fjob                    5
# reason                  4
# guardian                3
# traveltime              4
# studytime               4
# failures                4
# schoolsup               2
# famsup                  2
# paid                    2
# activities              2
# nursery                 2
# studytime, granular     4
# higher                  2
# internet                2
# romantic                2
# famrel                  6
# freetime                5
# goout                   5
# health                  5
# absences               36
# score                  18
# dtype: int64
#
# Количество пропущенных значений:
# address : 17
# famsize : 27
# Pstatus : 45
# Medu : 3
# Fedu : 24
# Mjob : 19
# Fjob : 36
# reason : 17
# guardian : 31
# traveltime : 28
# studytime : 7
# failures : 22
# schoolsup : 9
# famsup : 39
# paid : 40
# activities : 14
# nursery : 16
# studytime, granular : 7
# higher : 20
# internet : 34
# romantic : 31
# famrel : 27
# freetime : 11
# goout : 8
# health : 15
# absences : 12
# score : 6
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  392.000000  371.000000  367.000000  388.000000  373.000000
# mean    16.696203    2.750000    2.614555    1.438692    2.038660    0.337802
# std      1.276043    1.098127    2.228732    0.694181    0.842078    0.743135
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000   40.000000    4.000000    4.000000    3.000000
#
#        studytime, granular      famrel    freetime       goout      health  \
# count           388.000000  368.000000  384.000000  387.000000  380.000000
# mean             -6.115979    3.937500    3.231771    3.105943    3.531579
# std               2.526235    0.927277    0.993940    1.115896    1.396019
# min             -12.000000   -1.000000    1.000000    1.000000    1.000000
# 25%              -6.000000    4.000000    3.000000    2.000000    3.000000
# 50%              -6.000000    4.000000    3.000000    3.000000    4.000000
# 75%              -3.000000    5.000000    4.000000    4.000000    5.000000
# max              -3.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences       score
# count  383.000000  389.000000
# mean     7.279373   52.262211
# std     23.465197   22.919022
# min      0.000000    0.000000
# 25%      0.000000   40.000000
# 50%      4.000000   55.000000
# 75%      8.000000   70.000000
# max    385.000000  100.000000
#        school  sex address famsize Pstatus   Mjob   Fjob  reason guardian  \
# count     395  395     378     368     350    376    359     378      364
# unique      2    2       2       2       2      5      5       4        3
# top        GP    F       U     GT3       T  other  other  course   mother
# freq      349  208     295     261     314    133    197     137      250
#
#        schoolsup famsup paid activities nursery higher internet romantic
# count        386    356  355        381     379    375      361      364
# unique         2      2    2          2       2      2        2        2
# top           no    yes   no        yes     yes    yes      yes       no
# freq         335    219  200        195     300    356      305      240

# %% [markdown]
# ### Содержание датасета:
# 1. **school** — аббревиатура школы, в которой обучается ученик
#
# 2. **sex** — пол ученика (**'F'** - женский, **'M'** - мужской)
#
# 3. **age** — возраст ученика **(от 15 до 22)**
#
# 4. **address** — тип адреса ученика (**'U'** - городской, **'R'** - за городом)
#
# 5. **famsize** — размер семьи (**'LE3'** <= 3, **'GT3'** >3)
#
# 6. **Pstatus** — статус совместного проживания родителей (**'T'** - живут вместе **'A'** - раздельно)
#
# 7. **Medu** — образование матери (**0** - нет, **1** - окончила 4 класса, **2** - окончила 5-9 классов, **3** - среднее специальное или 11 классов, **4** - высшее)
#
# 8. **Fedu** — образование отца (**0** - нет, **1** - окончил 4 класса, **2** - окончил 5-9 классов, **3** - среднее специальное или 11 классов, **4** - высшее)
#
# 9. **Mjob** — работа матери (**'teacher'** - учитель, **'health'** - сфера здравоохранения, **'services'** - госслужба, **'at_home'** - не работает, **'other'** - другое)
#
# 10. **Fjob** — работа отца (**'teacher'** - учитель, **'health'** - сфера здравоохранения, **'services'** - госслужба, **'at_home'** - не работает, **'other'** - другое)
#
# 11. **reason** — причина выбора школы (**'home'** - близость к дому, **'reputation'** - репутация школы, **'course'** - образовательная программа, **'other'** - другое)
#
# 12. **guardian** — опекун (**'mother'** - мать, **'father'** - отец, **'other'** - другое)
#
# 13. **traveltime** — время в пути до школы (**1** - <15 мин., **2** - 15-30 мин., **3** - 30-60 мин., **4** - >60 мин.)
#
# 14. **studytime** — время на учёбу помимо школы в неделю (**1** - <2 часов, **2** - 2-5 часов, **3** - 5-10 часов, **4** - >10 часов)
#
# 15. **failures** — количество внеучебных неудач (**n**, если 1<=n<=3, иначе **0**)
#
# 16. **schoolsup** — дополнительная образовательная поддержка **(yes или no)**
#
# 17. **famsup** — семейная образовательная поддержка **(yes или no)**
#
# 18. **paid** — дополнительные платные занятия по математике **(yes или no)**
#
# 19. **activities** — дополнительные внеучебные занятия **(yes или no)**
#
# 20. **nursery** — посещал детский сад **(yes или no)**
#
# 21. **higher** — хочет получить высшее образование **(yes или no)**
#
# 22. **internet** — наличие интернета дома **(yes или no)**
#
# 23. **romantic** — в романтических отношениях **(yes или no)**
#
# 24. **famrel** — семейные отношения **(от 1 - очень плохо до 5 - очень хорошо)**
#
# 25. **freetime** — свободное время после школы (**от 1 - очень мало до 5 - очень мого)**
#
# 26. **goout** — проведение времени с друзьями **(от 1 - очень мало до 5 - очень много)**
#
# 27. **health** — текущее состояние здоровья **(от 1 - очень плохо до 5 - очень хорошо)**
#
# 28. **absences** — количество пропущенных занятий
#
# 29. **score** — баллы по госэкзамену по математике - **целевая переменная**

# %% [markdown]
# **Столбец 'studytime, granular'** в описании проекта не представлен. На данный момент не известно, что он обозначает. Возможно, позже мы увидим, что его можно просто удалить.

# %%
# Преобразуем названия колонок для удобства
display(df.columns)  
print(f'Переименуем столбец "studytime, granular"  в  "granular" для удобства')
df.rename(columns = {'studytime, granular' : 'granular'}, inplace = True)
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'score'],
#       dtype='object')
# Переименуем столбец "studytime, granular"  в  "granular" для удобства
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'granular', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'health', 'absences', 'score'],
#       dtype='object')

# %%
# Оценим визуально количество пропусков и их распределение
fig, ax = plt.subplots(figsize = (20,12))   
sns_heatmap = sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'tab20b')

# %% [markdown]
# # 3. Анализ категориальных и числовых переменных

# %% [markdown]
# ### Рассмотрим категориальные столбцы

# %%
# Выведем названия всех категориальных столбцов
for col in df.columns:
    if df[col].dtype == 'object':
        print(col)
# Out:
# school
# sex
# address
# famsize
# Pstatus
# Mjob
# Fjob
# reason
# guardian
# schoolsup
# famsup
# paid
# activities
# nursery
# higher
# internet
# romantic

# %%
# Применим функцию info_column, чтобы детальнее посмотреть на данные в категориальных столбцах
for col in df.columns:
    if df[col].dtype == 'object':
        column_info(df, col)
# Out:
#         count
# school
# GP        349
# MS         46
# Уникальных значений: 2
# Уникальные значения: ['GP' 'MS']
# Пропущенных значений: 0
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: school
# Non-Null Count  Dtype
# --------------  -----
# 395 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#      count
# sex
# F      208
# M      187
# Уникальных значений: 2
# Уникальные значения: ['F' 'M']
# Пропущенных значений: 0
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: sex
# Non-Null Count  Dtype
# --------------  -----
# 395 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#          count
# address
# U          295
# R           83
# Уникальных значений: 2
# Уникальные значения: ['U' nan 'R']
# Пропущенных значений: 17 из 395, что составляет: 4.3%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: address
# Non-Null Count  Dtype
# --------------  -----
# 378 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#          count
# famsize
# GT3        261
# LE3        107
# Уникальных значений: 2
# Уникальные значения: [nan 'GT3' 'LE3']
# Пропущенных значений: 27 из 395, что составляет: 6.84%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: famsize
# Non-Null Count  Dtype
# --------------  -----
# 368 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#          count
# Pstatus
# T          314
# A           36
# Уникальных значений: 2
# Уникальные значения: ['A' nan 'T']
# Пропущенных значений: 45 из 395, что составляет: 11.39%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: Pstatus
# Non-Null Count  Dtype
# --------------  -----
# 350 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#           count
# Mjob
# other       133
# services     98
# at_home      58
# teacher      55
# health       32
# Уникальных значений: 5
# Уникальные значения: ['at_home' 'health' 'other' 'services' 'teacher' nan]
# Пропущенных значений: 19 из 395, что составляет: 4.81%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: Mjob
# Non-Null Count  Dtype
# --------------  -----
# 376 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#           count
# Fjob
# other       197
# services    102
# teacher      29
# at_home      16
# health       15
# Уникальных значений: 5
# Уникальные значения: ['teacher' 'other' nan 'health' 'services' 'at_home']
# Пропущенных значений: 36 из 395, что составляет: 9.11%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: Fjob
# Non-Null Count  Dtype
# --------------  -----
# 359 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#             count
# reason
# course        137
# home          104
# reputation    103
# other          34
# Уникальных значений: 4
# Уникальные значения: ['course' 'other' 'home' 'reputation' nan]
# Пропущенных значений: 17 из 395, что составляет: 4.3%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: reason
# Non-Null Count  Dtype
# --------------  -----
# 378 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#           count
# guardian
# mother      250
# father       86
# other        28
# Уникальных значений: 3
# Уникальные значения: ['mother' 'father' 'other' nan]
# Пропущенных значений: 31 из 395, что составляет: 7.85%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: guardian
# Non-Null Count  Dtype
# --------------  -----
# 364 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#            count
# schoolsup
# no           335
# yes           51
# Уникальных значений: 2
# Уникальные значения: ['yes' 'no' nan]
# Пропущенных значений: 9 из 395, что составляет: 2.28%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: schoolsup
# Non-Null Count  Dtype
# --------------  -----
# 386 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#         count
# famsup
# yes       219
# no        137
# Уникальных значений: 2
# Уникальные значения: ['no' 'yes' nan]
# Пропущенных значений: 39 из 395, что составляет: 9.87%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: famsup
# Non-Null Count  Dtype
# --------------  -----
# 356 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#       count
# paid
# no      200
# yes     155
# Уникальных значений: 2
# Уникальные значения: ['no' nan 'yes']
# Пропущенных значений: 40 из 395, что составляет: 10.13%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: paid
# Non-Null Count  Dtype
# --------------  -----
# 355 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#             count
# activities
# yes           195
# no            186
# Уникальных значений: 2
# Уникальные значения: ['no' 'yes' nan]
# Пропущенных значений: 14 из 395, что составляет: 3.54%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: activities
# Non-Null Count  Dtype
# --------------  -----
# 381 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#          count
# nursery
# yes        300
# no          79
# Уникальных значений: 2
# Уникальные значения: ['yes' 'no' nan]
# Пропущенных значений: 16 из 395, что составляет: 4.05%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: nursery
# Non-Null Count  Dtype
# --------------  -----
# 379 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#         count
# higher
# yes       356
# no         19
# Уникальных значений: 2
# Уникальные значения: ['yes' nan 'no']
# Пропущенных значений: 20 из 395, что составляет: 5.06%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: higher
# Non-Null Count  Dtype
# --------------  -----
# 375 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#           count
# internet
# yes         305
# no           56
# Уникальных значений: 2
# Уникальные значения: [nan 'yes' 'no']
# Пропущенных значений: 34 из 395, что составляет: 8.61%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: internet
# Non-Null Count  Dtype
# --------------  -----
# 361 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None
#           count
# romantic
# no          240
# yes         124
# Уникальных значений: 2
# Уникальные значения: ['no' nan 'yes']
# Пропущенных значений: 31 из 395, что составляет: 7.85%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: romantic
# Non-Null Count  Dtype
# --------------  -----
# 364 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB
# None

# %% [markdown]
# ### Рассмотрим числовые столбцы
#
# **Выведем названия всех числовых столбцов и рассмотрим каждый из них более детально**

# %%
# Выведем названия всех числовых столбцов
for col in df.columns:
    if df[col].dtype != 'object':
        print(col)
# Out:
# age
# Medu
# Fedu
# traveltime
# studytime
# failures
# granular
# famrel
# freetime
# goout
# health
# absences
# score

# %% [markdown]
# ### Столбец 'age'

# %%
# Посмотрим на значения описательных статистик и построим гистограмму распределения 
print(f'Количество уникальных значений в столбце "age": {df.age.nunique()}.\nУникальные значения: {sorted(df.age.unique())}.')
df.age.hist(bins = 20)
display(df.age.describe())
# Out:
# Количество уникальных значений в столбце "age": 8.
# Уникальные значения: [15, 16, 17, 18, 19, 20, 21, 22].
# count    395.000000
# mean      16.696203
# std        1.276043
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize = (6, 1.5))
sns.boxplot(data = df, x = 'age')
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# График boxplot показывает, что значение возраста "22" может являться выбросом.
# Воспользуемся тремя различными способами определения выбросов:
# - поиском по отклонению (z-score),
# - формулой интерквартильного расстояния (межквартильного размаха),
# - поиском по распределению.
#
# Все функции помещены в начало проекта в раздел "Импорт данных и вспомогательные функции".

# %% [markdown]
# **Поиск выбросов по отклонению (z-score)**
# Этот метод основан на поиске значения, на которое отклоняется данная точка от среднего. В таком случае используют z-score, то есть расстояние (измеряемое в количестве стандартных отклонений) от среднего значения точек.

# %%
outliers = outliers_z_score(df.age, threshold = 3)
print(f'Количество выявленных выбросов с помощью z-score: {len(outliers)}\n\nЗначения, определенные как выбросы:')
df.age.iloc[outliers].to_frame()
# Out:
# Количество выявленных выбросов с помощью z-score: 2
#
# Значения, определенные как выбросы:
#      age
# 247   22
# 392   21

# %% [markdown]
# **Формула межквартильного расстояния**
# Выбросами считаются значения, которые лежат вне рамок:
# [percentile(25) -1.5 * IQR : percentile(75)+1.5 * IQR],
# где IQR = percentile(75) - percentile(25).

# %%
outliers = outliers_iqr(df.age)
print(f'Количество выявленных выбросов с помощью формулы межквартильного расстояния: {len(outliers)}\n\nЗначения, определенные как выбросы:')
df.age.iloc[outliers].to_frame()
# Out:
# Количество выявленных выбросов с помощью формулы межквартильного расстояния: 1
#
# Значения, определенные как выбросы:
#      age
# 247   22

# %% [markdown]
# **Поиск по распределению**
# Построим нормальное распределение поверх данных, посчитаем вероятность нахождения в данном распределении для каждого значения.
# Самые невероятные значения считаются выбросами.

# %%
mu, sigma = estimate_gaussian(df.age)
distribution = get_gaussian(mu, sigma)
probabilities = get_probs(distribution, df.age)
display(round(round(pd.Series(probabilities),3).value_counts(normalize = True),3).reset_index().sort_values(by = 'index', ascending = False))

# Выберем значение вероятности (0.03), ниже которого будем считать точку выбросом и посчитаем количество выбросов
outl = np.where(probabilities < 0.03)[0]
print(f'Количество выявленных выбросов с помощью поиска по распределению: {len(outl)}\n\nЗначения, определенные как выбросы:')
df.age.iloc[outl].to_frame()
# Out:
#    index  proportion
# 1  0.241       0.248
# 0  0.224       0.263
# 2  0.178       0.208
# 3  0.142       0.208
# 4  0.090       0.061
# 5  0.031       0.008
# 7  0.007       0.003
# 6  0.001       0.003
# Количество выявленных выбросов с помощью поиска по распределению: 2
#
# Значения, определенные как выбросы:
#      age
# 247   22
# 392   21

# %% [markdown]
# Несмотря на тот факт, что три различные проверки определили значение возраста "22" как выброс, это значение можно не считать выбросом, т.к. заявленная **цель проекта — отследить влияние условий жизни учащихся в возрасте от 15 до 22 лет на их успеваемость**. Наблюдаемый минимум и максимум входят в этот промежуток по условию задачи, поэтому удалять это значение не будем.

# %% [markdown]
# ### Столбец 'Medu'

# %%
# Выведем более детальную информацию о колонке
column_info(df, 'Medu')
# Out:
#       count
# Medu
# 4.0     131
# 2.0     102
# 3.0      97
# 1.0      59
# 0.0       3
# Уникальных значений: 5
# Уникальные значения: [ 4.  1.  3.  2. nan  0.]
# Пропущенных значений: 3 из 395, что составляет: 0.76%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: Medu
# Non-Null Count  Dtype
# --------------  -----
# 392 non-null    float64
# dtypes: float64(1)
# memory usage: 3.2 KB
# None

# %%
# Посмотрим на значения описательных статистик и построим гистограмму распределения 
df.Medu.plot(kind = 'hist', grid = True, colormap = 'coolwarm', title = 'Medu', color = 'pink', bins = 20)
display(df.Medu.describe())
# Out:
# count    392.000000
# mean       2.750000
# std        1.098127
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: Medu, dtype: float64

# %% [markdown]
# ### Столбец 'Fedu'

# %%
# Выведем более детальную информацию о колонке 
column_info(df, 'Fedu')
# Out:
#       count
# Fedu
# 2.0     106
# 3.0      96
# 4.0      88
# 1.0      78
# 0.0       2
# 40.0      1
# Уникальных значений: 6
# Уникальные значения: [ 4.  1.  2.  3. 40. nan  0.]
# Пропущенных значений: 24 из 395, что составляет: 6.08%
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 395 entries, 0 to 394
# Series name: Fedu
# Non-Null Count  Dtype
# --------------  -----
# 371 non-null    float64
# dtypes: float64(1)
# memory usage: 3.2 KB
# None

# %%
# Посмотрим на значения описательных статистик и построим гистограмму распределения 
df.Fedu.plot(kind = 'hist', grid = True, colormap = 'coolwarm', title = 'Fedu', color = 'blue', bins = 20)
display(df.Fedu.describe())
# Out:
# count    371.000000
# mean       2.614555
# std        2.228732
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max       40.000000
# Name: Fedu, dtype: float64

# %% [markdown]
# Судя по графику, в данных присутствует явный выброс - значение 40. Избавимся от наблюдений, которые имеют некорректное значение.

# %%
# df.Fedu = df['Fedu'].apply(lambda x : x if x in range(0, 5) else np.nan)
# df.Fedu.value_counts(dropna = False)

# Избавимся от наблюдений, которые имеют некорректное значение 
df = df.loc[df.Fedu < 5]
df.Fedu.plot(kind = 'hist', grid = True, legend = False, colormap = 'coolwarm', title = 'Fedu', color = 'blue', bins = 20)
# Out:
# <AxesSubplot:title={'center':'Fedu'}, ylabel='Frequency'>

# %% [markdown]
# ### Столбец  'traveltime'

# %%
# Выведем более детальную информацию о колонке и построим график распределения 
ax = sns.displot(df, x = 'traveltime', color = "gray", height = 3.5, legend = True)
plt.title("Traveltime")
column_info(df, 'traveltime')
# Out:
#             count
# traveltime
# 1.0           225
# 2.0            92
# 3.0            21
# 4.0             7
# Уникальных значений: 4
# Уникальные значения: [ 2.  1.  3. nan  4.]
# Пропущенных значений: 25 из 370, что составляет: 6.76%
#
# <class 'pandas.core.series.Series'>
# Index: 370 entries, 0 to 394
# Series name: traveltime
# Non-Null Count  Dtype
# --------------  -----
# 345 non-null    float64
# dtypes: float64(1)
# memory usage: 13.9 KB
# None

# %% [markdown]
# ### Столбец 'studytime'

# %%
ax = sns.histplot(df.studytime, color = "gray")
ax.set_title('Studytime')
column_info(df, 'studytime')
# Out:
#            count
# studytime
# 2.0          182
# 1.0           98
# 3.0           58
# 4.0           25
# Уникальных значений: 4
# Уникальные значения: [ 2.  3.  1. nan  4.]
# Пропущенных значений: 7 из 370, что составляет: 1.89%
#
# <class 'pandas.core.series.Series'>
# Index: 370 entries, 0 to 394
# Series name: studytime
# Non-Null Count  Dtype
# --------------  -----
# 363 non-null    float64
# dtypes: float64(1)
# memory usage: 13.9 KB
# None

# %% [markdown]
# ### Столбец 'failures'

# %%
# Выведем более детальную информацию о колонке и построим гистограмму распределения 
ax = sns.displot(df, x = df.failures, height = 3.5, kde = True)
plt.title("Failures")
column_info(df, 'failures')
# Out:
#           count
# failures
# 0.0         277
# 1.0          45
# 3.0          15
# 2.0          14
# Уникальных значений: 4
# Уникальные значения: [ 0.  3.  2.  1. nan]
# Пропущенных значений: 19 из 370, что составляет: 5.14%
#
# <class 'pandas.core.series.Series'>
# Index: 370 entries, 0 to 394
# Series name: failures
# Non-Null Count  Dtype
# --------------  -----
# 351 non-null    float64
# dtypes: float64(1)
# memory usage: 13.9 KB
# None

# %% [markdown]
# ### Столбец 'granular'

# %%
# Выведем более детальную информацию о колонке и построим гистограмму распределения 
ax = sns.displot(df, x = df.granular, bins = 20, height = 3.5, kde = True )
plt.title('Granular')
column_info(df, 'granular')
df.granular.describe()
# Out:
#           count
# granular
# -6.0        182
# -3.0         98
# -9.0         58
# -12.0        25
# Уникальных значений: 4
# Уникальные значения: [ -6.  -9.  -3.  nan -12.]
# Пропущенных значений: 7 из 370, что составляет: 1.89%
#
# <class 'pandas.core.series.Series'>
# Index: 370 entries, 0 to 394
# Series name: granular
# Non-Null Count  Dtype
# --------------  -----
# 363 non-null    float64
# dtypes: float64(1)
# memory usage: 13.9 KB
# None
# count    363.000000
# mean      -6.082645
# std        2.521466
# min      -12.000000
# 25%       -6.000000
# 50%       -6.000000
# 75%       -3.000000
# max       -3.000000
# Name: granular, dtype: float64

# %%
# Построим boxplot, чтобы взглянуть на плотность распределения и потенциальные выбросы
fig = plt.figure(figsize = (5, 1.3))
sns.boxplot(data = df, x = df.granular, flierprops = {"marker" : "x"}, medianprops = {"color" : "coral"},
            boxprops = {"facecolor": (.4, .6, .8, .5)})
# Out:
# <AxesSubplot:xlabel='granular'>

# %% [markdown]
# График boxplot показывает, что в колонке 'granular', возможно, присутствуют выбросы. Однако, в справочном материале к данному проекту об этой переменной нет какой-либо информации. Возможно, далее по ходу проведения анализа данных станет понятно, что означает эта переменная.
# Пока что не будем производить с ней какие-либо действия.

# %% [markdown]
# ### Столбец 'famrel'

# %%
# Выведем более детальную информацию о колонке и построим гистограмму распределения 
df.famrel.hist(bins = 20, grid = True)
column_info(df, 'famrel')
# Out:
#         count
# famrel
#  4.0      168
#  5.0       95
#  3.0       59
#  2.0       16
#  1.0        7
# -1.0        1
# Уникальных значений: 6
# Уникальные значения: [ 4.  5.  3. nan -1.  2.  1.]
# Пропущенных значений: 24 из 370, что составляет: 6.49%
#
# <class 'pandas.core.series.Series'>
# Index: 370 entries, 0 to 394
# Series name: famrel
# Non-Null Count  Dtype
# --------------  -----
# 346 non-null    float64
# dtypes: float64(1)
# memory usage: 13.9 KB
# None

# %% [markdown]
# Согласно справочной информации, переменная famrel — семейные отношения — имеет градацию от 1 (очень плохо) до 5 (очень хорошо).
# Значение "-1" может быть ошибкой ввода. Возможно, на этом месте должно быть значение "1". Для проверки этой гипотезы можно построить вспомогательную модель, которая выявит закономерности и определит более точное значение этого наблюдения. Однако, на данный момент мы не можем однозначно ответить на этот вопрос, поэтому избавимся от этого наблюдения.

# %%
# Избавимся от значения признака '-1' и построим гистограмму
df = df.loc[df.famrel > 0]
df.famrel.hist(bins = 20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Столбец 'freetime'

# %%
# Выведем более детальную информацию о колонке и построим график распределения 
ax = sns.displot(df, x = df.freetime, height = 3.5)
plt.title('Freetime')
column_info(df, 'freetime')
# Out:
#           count
# freetime
# 3.0         134
# 4.0          97
# 2.0          54
# 5.0          34
# 1.0          17
# Уникальных значений: 5
# Уникальные значения: [ 3.  2.  4.  1.  5. nan]
# Пропущенных значений: 9 из 345, что составляет: 2.61%
#
# <class 'pandas.core.series.Series'>
# Index: 345 entries, 0 to 394
# Series name: freetime
# Non-Null Count  Dtype
# --------------  -----
# 336 non-null    float64
# dtypes: float64(1)
# memory usage: 13.5 KB
# None

# %% [markdown]
# ### Столбец 'goout'

# %%
# Выведем более детальную информацию о колонке и построим гистограмму распределения 
df.goout.hist(bins = 20)
column_info(df, 'goout')
# Out:
#        count
# goout
# 3.0      115
# 2.0       87
# 4.0       71
# 5.0       45
# 1.0       19
# Уникальных значений: 5
# Уникальные значения: [ 4.  3.  2.  1.  5. nan]
# Пропущенных значений: 8 из 345, что составляет: 2.32%
#
# <class 'pandas.core.series.Series'>
# Index: 345 entries, 0 to 394
# Series name: goout
# Non-Null Count  Dtype
# --------------  -----
# 337 non-null    float64
# dtypes: float64(1)
# memory usage: 13.5 KB
# None

# %% [markdown]
# ### Столбец 'health'

# %%
# Выведем более детальную информацию о колонке и построим гистограмму распределения 
df.health.hist(bins = 20)
column_info(df, 'health')
# Out:
#         count
# health
# 5.0       111
# 3.0        81
# 4.0        58
# 1.0        42
# 2.0        40
# Уникальных значений: 5
# Уникальные значения: [ 3.  5.  1.  2.  4. nan]
# Пропущенных значений: 13 из 345, что составляет: 3.77%
#
# <class 'pandas.core.series.Series'>
# Index: 345 entries, 0 to 394
# Series name: health
# Non-Null Count  Dtype
# --------------  -----
# 332 non-null    float64
# dtypes: float64(1)
# memory usage: 13.5 KB
# None

# %% [markdown]
# ### Столбец 'absences'

# %%
# Выведем значения описательных статистик и построим гистограмму распределения 
print(f"Количество уникальных значений признака 'absences': {df.absences.nunique()}")
df.absences.hist(bins = 25)
df.absences.describe()
# Out:
# Количество уникальных значений признака 'absences': 33
# count    333.000000
# mean       7.315315
# std       24.755302
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max      385.000000
# Name: absences, dtype: float64

# %%
# Построим boxplot, чтобы взглянуть на плотность распределения и потенциальные выбросы
fig = plt.figure(figsize = (5, 1.3))
sns.boxplot(data = df, x = df.absences, flierprops = {"marker" : "x"},
            boxprops = {"facecolor" : (.4, .6, .8, .5)})
# Out:
# <AxesSubplot:xlabel='absences'>

# %% [markdown]
# На графике видно, что данные распределены ассиметрично. Чтобы исправить ситуацию, можно извлечь корень, возвести в степень или прологарифмировать переменную. **Возьмем логарифм переменной 'absences', чтобы уменьшить перепады и сгладить "хвост" (прибавим к значениям единицу, чтобы не получть "inf")**

# %%
# Прологарифмируем переменную и построим график
# np.log(df.absences +1)
df.absences = df.absences.apply(lambda x: np.log(x + 1))

df.absences.hist(bins = 30)
fig = plt.figure(figsize = (5, 1.3))
sns.boxplot(data = df, x = 'absences')
# Out:
# <AxesSubplot:xlabel='absences'>

# %% [markdown]
# ### Столбец 'score' - целевая переменная

# %%
# Выведем значения описательных статистик и построим гистограмму распределения 
df.score.hist(bins = 25)
display(df.score.describe())
print(f'Количество уникальных значений признака "score": {df.score.nunique()}\nУникальные значения в порядке возрастания: {sorted(df.score.unique())}')

# Построим boxplot, чтобы посмотреть плотность распределения и потенциальные выбросы
fig = plt.figure(figsize = (7, 2))
sns.boxplot(data = df, x = df.score, flierprops = {"marker" : "x"}, medianprops = {"color" : "coral"},
            boxprops = {"facecolor": (.4, .6, .8, .5)}, notch = True)
# Out:
# count    339.000000
# mean      52.477876
# std       22.556214
# min        0.000000
# 25%       42.500000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64
# Количество уникальных значений признака "score": 18
# Уникальные значения в порядке возрастания: [0.0, 20.0, 25.0, 30.0, 35.0, 40.0, 45.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 85.0, 90.0, 95.0, 100.0, nan]
# <AxesSubplot:xlabel='score'>

# %% [markdown]
# График показывает, что в данных явно присутствуют выбросы. **Посмотрим детальнее с помощью формулы межквартильного расстояния**.
# (Функция для нахождения выбросов с помощью межквартильного расстояния помещена в начало проекта в раздел "Вспомогательные функции").

# %%
outliers = outliers_iqr(df.score.dropna())
print(f'Количество выявленных выбросов с помощью формулы межквартильного расстояния: {len(outliers)}')

outliers_nunique = df.score.dropna().iloc[outliers].to_frame().score.nunique()
outliers_unique = df.score.dropna().iloc[outliers].to_frame().score.unique()
print(f'Количество уникальных значений среди выбросов: {outliers_nunique}\nУникальное значение: {outliers_unique}')
# Out:
# Количество выявленных выбросов с помощью формулы межквартильного расстояния: 31
# Количество уникальных значений среди выбросов: 1
# Уникальное значение: [0.]

# %% [markdown]
# Проверка с помощью межквартильного расстояния выявила 31 экстремально низкое значение. Избавимся от выбросов.

# %%
# Избавимся от выбросов и посмотрим распределение
df = df.loc[df.score > 10]
df.score.hist(bins = 25)
df.score.describe()
# Out:
# count    308.000000
# mean      57.759740
# std       15.940057
# min       20.000000
# 25%       50.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %% [markdown]
# # 4. Корреляционный анализ

# %% [markdown]
# Некоторые признаки могут быть сильно скоррелированы друг с другом. Это означает, что между этими признаками есть некоторая линейная зависимость. Если зависимость большая - часть скоррелированных признаков (возможно, не все) следует убрать из выборки, так как они несут избыточную информацию. **Посчитаем матрицу корреляции и построим pairplot и heatmap.**

# %%
sns.pairplot(df, kind = 'reg')

# %% [markdown]
# Из анализа очевидно, что столбец granular обратно пропорционален столбцу studytime, избавимся от него.

# %%
# df.corr().applymap(lambda x: x if x > 0.5 else '')

# %%
# Удалим столбец granular
df = df.drop('granular', axis = 1)

# Построим таблицу heatmap
plt.rcParams['figure.figsize'] = (15, 15)
ax = sns.heatmap(df.corr(), annot = True, cmap = sns.cubehelix_palette(as_cmap = True), linewidth = .1, fmt = ".2f")
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_tick_params(rotation = 90)

# %%
# Рассмотрим подближе корреляцию только для числовых столбцов
col_list = []
for col in df.columns:
    if (df[col].dtype != 'object') and (len(df[col].unique()) > 6):
        col_list.append(col)

plt.rcParams['figure.figsize'] = (3.5, 2.5)
sns.heatmap(df[col_list].corr(), annot = True, cmap = 'cool', linewidth = .1, fmt = '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# График показывает, что возраст отрицательно коррелирует с целевой переменной

# %%
df.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.120544 -0.132904    0.081953  -0.029029  0.268951
# Medu       -0.120544  1.000000  0.623277   -0.153984   0.081203 -0.193629
# Fedu       -0.132904  0.623277  1.000000   -0.181685  -0.007760 -0.266626
# traveltime  0.081953 -0.153984 -0.181685    1.000000  -0.119623  0.091287
# studytime  -0.029029  0.081203 -0.007760   -0.119623   1.000000 -0.138870
# failures    0.268951 -0.193629 -0.266626    0.091287  -0.138870  1.000000
# famrel      0.067594 -0.015481 -0.027716   -0.054459   0.037804  0.035149
# freetime   -0.013682  0.006043 -0.027693    0.005918  -0.123678  0.136043
# goout       0.091383  0.093004  0.037420    0.023772  -0.047060  0.111910
# health     -0.054718 -0.064927  0.006017   -0.000081  -0.100978  0.055280
# absences    0.215375  0.060477  0.008078   -0.039531  -0.054154  0.166638
# score      -0.135764  0.180558  0.136063   -0.081853   0.149390 -0.272112
#
#               famrel  freetime     goout    health  absences     score
# age         0.067594 -0.013682  0.091383 -0.054718  0.215375 -0.135764
# Medu       -0.015481  0.006043  0.093004 -0.064927  0.060477  0.180558
# Fedu       -0.027716 -0.027693  0.037420  0.006017  0.008078  0.136063
# traveltime -0.054459  0.005918  0.023772 -0.000081 -0.039531 -0.081853
# studytime   0.037804 -0.123678 -0.047060 -0.100978 -0.054154  0.149390
# failures    0.035149  0.136043  0.111910  0.055280  0.166638 -0.272112
# famrel      1.000000  0.147663  0.047466  0.125532 -0.115497  0.020343
# freetime    0.147663  1.000000  0.273381  0.124335  0.011048 -0.009284
# goout       0.047466  0.273381  1.000000 -0.017961  0.110837 -0.160280
# health      0.125532  0.124335 -0.017961  1.000000 -0.065864 -0.056890
# absences   -0.115497  0.011048  0.110837 -0.065864  1.000000 -0.172132
# score       0.020343 -0.009284 -0.160280 -0.056890 -0.172132  1.000000

# %%
# Корреляция признаков с целевой переменной
round(df.corr().score.abs().sort_values(ascending = False), 2)
# Out:
# score         1.00
# failures      0.27
# Medu          0.18
# absences      0.17
# goout         0.16
# studytime     0.15
# Fedu          0.14
# age           0.14
# traveltime    0.08
# health        0.06
# famrel        0.02
# freetime      0.01
# Name: score, dtype: float64

# %% [markdown]
# - Признаки несильно коррелируют друг с другом. Это может быть хорошим знаком для построения модели, однако осутствие сильной корреляции с целевой переменной - вовсе не позитивный факт.
#
# - Сортировка признака "score" по значению модуля коэффициента корреляции не учитывает, что переменные в этом столбце не являются абсолютно независимыми. Для устранения этого недостатка используем значение коэффициента детерминации (доля дисперсии зависимой переменной, объясняемая рассматриваемой моделью). В зависимости от наличия определённых переменных в модели, связь между содержащимися в ней переменными и целевым параметром прослеживается наилучшим образом.

# %%
# Рекурсивно переберём все сочетания переменных
variables = {'age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 
             'famrel', 'freetime', 'goout', 'health', 'absences'}

# Найдём такой набор признаков, при котором коэффициент детерминации (R-squared) будет максимальным
bruteforce_variables = set()
BruteForce(variables, '', bruteforce_variables)
bruteforce_variables.remove('')
bruteforce_variables
# Out:
# {'Medu + freetime + failures + Fedu + age + traveltime + studytime',
#  'Medu + health + Fedu + studytime + failures',
#  'Medu + absences + freetime + failures + age + goout',
#  'health + famrel + failures + Fedu + traveltime',
#  'absences + freetime + failures + traveltime + studytime + goout',
#  'Medu + health + freetime + Fedu + failures + goout',
#  'Medu + absences + freetime + goout',
#  'Medu + absences + Fedu + failures + age',
#  'Medu + absences + failures + Fedu + traveltime + studytime',
#  'Medu + health + absences + famrel + studytime + failures + age + goout',
#  'health + famrel + failures + age + studytime + goout',
#  'health + famrel + freetime + traveltime + goout',
#  'Medu + health + absences + freetime + traveltime + studytime + goout',
#  'health + absences + famrel + freetime + failures + Fedu + studytime + goout',
#  'Medu + absences + Fedu + failures + traveltime',
#  'Medu + health + famrel + failures + traveltime + studytime + goout',
#  'health + famrel + freetime + failures + age + traveltime + studytime + goout',
#  'health + absences + freetime + studytime + age + traveltime + goout',
#  'Medu + absences + freetime + Fedu + failures + age + goout',
#  'Medu + health + absences + failures + Fedu + studytime',
#  'health + failures + age + traveltime + studytime + goout',
#  'Medu + health + absences + studytime + failures + age',
#  'Medu + health + famrel + failures + age + studytime + goout',
#  'health + absences + famrel + studytime + failures + age',
#  'health + absences + famrel + freetime + age + goout',
#  'absences + failures',
#  'health + freetime + Fedu + age + studytime + goout',
#  'health + absences + famrel + freetime + Fedu + traveltime + studytime + goout',
#  'health + famrel + freetime + studytime',
#  'Medu + absences + famrel + failures + age + traveltime + studytime',
#  'health + absences + studytime + failures + age + goout',
#  'health + absences + famrel + age + studytime + goout',
#  'Medu + famrel + failures + Fedu + traveltime + goout',
#  'age + goout',
#  'health + failures + goout',
#  'Medu + health + absences + failures + traveltime',
#  'health + freetime + failures + studytime',
#  'absences + failures + Fedu + age + traveltime',
#  'Medu + health + freetime + age + studytime',
#  'absences + freetime + studytime + age',
#  'health + famrel + Fedu + failures + studytime',
#  'famrel + failures + Fedu + age + traveltime',
#  'Medu + health + Fedu + age + traveltime',
#  'Fedu + failures + traveltime',
#  'Medu + health + absences + freetime + Fedu + failures + age + goout',
#  'Medu + famrel + freetime + Fedu + age + traveltime',
#  'health + freetime + failures + age + studytime',
#  'Medu + health + absences + freetime + failures + traveltime + studytime + goout',
#  'absences + freetime + age + traveltime + studytime',
#  'Medu + absences + Fedu + traveltime + goout',
#  'failures + studytime',
#  'Medu + health + failures + age + traveltime + studytime + goout',
#  'Medu + absences + freetime + studytime + traveltime',
#  'health + freetime + Fedu + failures + age + goout',
#  'Medu + absences + famrel + freetime + age + studytime + goout',
#  'Medu + health + absences + freetime + failures + age + traveltime + studytime',
#  'Medu + health + absences + famrel + failures + age + traveltime',
#  'Medu + health + absences + famrel + failures + age + traveltime + studytime',
#  'Medu + health + famrel + freetime + studytime',
#  'Medu + health + studytime + age',
#  'Fedu + traveltime + studytime + goout',
#  'Medu + famrel + failures + Fedu + traveltime + studytime',
#  'Medu + health + absences + freetime + Fedu + failures + studytime',
#  'health + absences + freetime + studytime + traveltime + goout',
#  'Medu + health + absences + famrel + failures + goout',
#  'Medu + health + famrel + freetime + failures + Fedu + traveltime + studytime + goout',
#  'Medu + absences + famrel + age + studytime',
#  'health + freetime + failures + Fedu + age + traveltime + goout',
#  'freetime + failures + studytime',
#  'traveltime',
#  'absences + famrel + failures',
#  'health + Fedu + studytime + age + traveltime + goout',
#  'Medu + freetime + Fedu + failures + traveltime + goout',
#  'famrel + freetime + failures + age',
#  'health + famrel + freetime + failures + goout',
#  'health + absences + freetime',
#  'Medu + absences + famrel + freetime + Fedu + traveltime + goout',
#  'Medu + health + failures + goout',
#  'health + failures + age + traveltime',
#  'famrel + failures + Fedu + age',
#  'Medu + health + freetime + failures + Fedu + age + traveltime + studytime',
#  'Medu + health + failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + absences + famrel + Fedu + failures + age',
#  'health + absences + famrel + freetime + failures + traveltime',
#  'health + freetime + Fedu + failures + age + studytime + goout',
#  'health + absences + failures + Fedu + age + studytime + goout',
#  'Medu + health + Fedu + traveltime + studytime',
#  'Medu + absences + failures + studytime + goout',
#  'freetime + studytime + failures + age + traveltime + goout',
#  'health + absences + studytime + failures + age + traveltime',
#  'Medu + health + studytime + failures + traveltime',
#  'Medu + absences + famrel + freetime + failures + Fedu + age + studytime + goout',
#  'health + absences + failures + Fedu + age + traveltime + goout',
#  'Medu + health + absences + Fedu + failures + traveltime + studytime',
#  'health + famrel + goout',
#  'failures + Fedu + age + goout',
#  'health + absences + famrel + studytime + goout',
#  'Medu + health + freetime + failures + age + goout',
#  'health + freetime + Fedu + failures + traveltime + studytime + goout',
#  'health + Fedu + age + traveltime + studytime + goout',
#  'Medu + health + absences + famrel + traveltime',
#  'Medu + health + absences + failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + health + famrel + freetime + age + studytime + goout',
#  'absences + famrel + freetime + failures + goout',
#  'freetime + failures + Fedu + studytime + goout',
#  'health + absences + Fedu + failures + age + traveltime + studytime',
#  'Medu + health + absences + Fedu + traveltime',
#  'freetime + failures',
#  'Medu + freetime + Fedu + failures + age + goout',
#  'health + famrel + age + goout',
#  'Medu + famrel + Fedu + failures + studytime + goout',
#  'absences + freetime + failures + Fedu + age + goout',
#  'Medu + health + absences + Fedu + studytime + failures + age + goout',
#  'famrel + Fedu + failures + traveltime + studytime + goout',
#  'Medu + studytime + failures + age + traveltime + goout',
#  'absences + age + traveltime + studytime',
#  'health + famrel + failures + age + studytime',
#  'absences + Fedu + studytime + failures + traveltime',
#  'Medu + health + absences + famrel',
#  'Medu + absences + famrel + freetime + Fedu + age',
#  'Medu + health + freetime + Fedu + failures + traveltime + goout',
#  'Medu + absences + famrel + age + traveltime + studytime',
#  'Medu + health + famrel + freetime + traveltime + studytime + goout',
#  'Medu + health + studytime + failures',
#  'absences + studytime + failures + age',
#  'absences + freetime + Fedu + failures + goout',
#  'Medu + absences + failures + Fedu + age + studytime',
#  'Medu + freetime + studytime + traveltime',
#  'health + famrel + failures + age + traveltime + goout',
#  'Medu + absences + Fedu + studytime',
#  'Medu + health + freetime + age + traveltime + goout',
#  'Medu + absences + freetime + failures + Fedu + age + goout',
#  'Medu + health + absences + famrel + freetime + failures + traveltime',
#  'Medu + health + freetime + Fedu + failures + age + studytime',
#  'health + absences + famrel + studytime + failures + traveltime + goout',
#  'health + freetime + Fedu + traveltime + studytime + goout',
#  'absences + freetime + age + studytime + goout',
#  'Medu + health + freetime + Fedu + goout',
#  'health + absences + famrel + Fedu + failures + age + traveltime + studytime + goout',
#  'Medu + traveltime + goout',
#  'health + Fedu + failures + traveltime + studytime',
#  'health + famrel + freetime + failures + traveltime',
#  'absences + freetime + failures + Fedu + traveltime',
#  'Fedu + studytime + age + traveltime',
#  'Medu + famrel + freetime + failures + Fedu + age',
#  'health + absences + famrel + freetime + failures + Fedu + goout',
#  'health + absences + famrel + failures + Fedu + traveltime',
#  'Medu + absences + famrel + failures + age + traveltime',
#  'health + famrel + failures + Fedu + studytime + goout',
#  'famrel + failures + traveltime + goout',
#  'Medu + absences + famrel + failures + Fedu + studytime + goout',
#  'Medu + health + absences + freetime + studytime + age + traveltime + goout',
#  'Medu + freetime + age + traveltime + studytime',
#  'health + Fedu + studytime + failures + traveltime',
#  'absences + famrel + freetime + traveltime',
#  'health + freetime + failures + studytime + goout',
#  'health + absences + failures + age + studytime',
#  'health + absences + Fedu + studytime + age + traveltime',
#  'Medu + freetime + failures + Fedu + traveltime + studytime + goout',
#  'Medu + studytime + failures',
#  'Medu + health + absences + freetime + studytime + goout',
#  'health + famrel + failures + traveltime + goout',
#  'Medu + health + Fedu + age + goout',
#  'health',
#  'Medu + health + absences + famrel + freetime + failures',
#  'health + absences + famrel + freetime + Fedu + goout',
#  'Medu + health + absences + failures + Fedu + studytime + goout',
#  'health + famrel + studytime + traveltime',
#  'health + famrel + Fedu',
#  'Fedu + traveltime + studytime',
#  'absences + freetime + studytime + failures + age + goout',
#  'Medu + health + absences + famrel + Fedu + failures + traveltime + studytime',
#  'Medu + health + absences + failures + traveltime + goout',
#  'Medu + absences + famrel + Fedu + failures + traveltime + goout',
#  'Medu + health + absences + famrel + failures + Fedu + traveltime + studytime + goout',
#  'absences',
#  'Medu + health + freetime + Fedu + age + studytime',
#  'health + absences + famrel + freetime + Fedu + age + goout',
#  'Medu + absences + famrel + freetime + failures + traveltime + goout',
#  'Medu + health + Fedu + studytime + age',
#  'Medu + absences + famrel + Fedu + failures + age + studytime + goout',
#  'health + failures + Fedu + age + traveltime + studytime',
#  'freetime + Fedu + failures',
#  'Medu + health + absences + freetime + age + traveltime + goout',
#  'Medu + health + famrel + freetime + Fedu',
#  'health + famrel + freetime + failures + traveltime + studytime',
#  'absences + famrel + studytime + traveltime + goout',
#  'Medu + absences + freetime + failures + Fedu + age + traveltime + studytime',
#  'Medu + famrel + Fedu + age + traveltime + studytime + goout',
#  'Medu + health + absences + traveltime + goout',
#  'Medu + health + famrel + Fedu + traveltime + studytime + goout',
#  'famrel + age + studytime',
#  'Medu + freetime + failures + Fedu + traveltime + goout',
#  'freetime + Fedu + age + traveltime + goout',
#  'Fedu + studytime + age',
#  'Medu + absences + Fedu + age + traveltime + studytime + goout',
#  'Medu + famrel + freetime + failures + Fedu + traveltime',
#  'health + freetime + Fedu + failures + age + traveltime + goout',
#  'health + absences + famrel + studytime + failures + age + traveltime + goout',
#  'Medu + health + absences + famrel + freetime + age',
#  'Medu + absences + famrel + freetime + traveltime + studytime',
#  'Medu + famrel + freetime + failures + Fedu + studytime + goout',
#  'Medu + absences + freetime + failures + Fedu + traveltime + studytime',
#  'Medu + famrel + Fedu + age + traveltime',
#  'health + Fedu + goout',
#  'Medu + health + absences + studytime + failures + age + goout',
#  'absences + studytime + failures + goout',
#  'health + freetime + age + goout',
#  'health + age',
#  'Fedu + studytime + failures + goout',
#  'Medu + famrel + freetime + failures + Fedu',
#  'health + traveltime + goout',
#  'health + absences + traveltime + studytime',
#  'Medu + health + traveltime',
#  'freetime + failures + Fedu + age + goout',
#  'Medu + health + freetime + failures + Fedu + age + goout',
#  'health + absences + age + studytime + goout',
#  'Medu + famrel + failures',
#  'health + Fedu + failures + age + goout',
#  'famrel + traveltime + studytime + goout',
#  'Medu + absences + famrel',
#  'Medu + failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + failures + Fedu + age + traveltime',
#  'Fedu + studytime + traveltime + goout',
#  'Medu + freetime + studytime + failures',
#  'absences + failures + goout',
#  'absences + freetime + Fedu + failures + age + studytime + goout',
#  'Medu + health + absences + Fedu + failures + age + traveltime + goout',
#  'Medu + health + absences + famrel + freetime + failures + age + traveltime + studytime + goout',
#  'famrel + traveltime + studytime',
#  'absences + freetime + Fedu + failures + traveltime + studytime',
#  'Medu + Fedu + studytime + failures + age',
#  'Medu + health + absences + famrel + Fedu + age + traveltime + studytime',
#  'Medu + absences + studytime + goout',
#  'Medu + health + absences + famrel + studytime + traveltime',
#  'Medu + freetime + Fedu + traveltime + studytime',
#  'Medu + health + absences + freetime + Fedu + age + traveltime + studytime + goout',
#  'Medu + famrel + freetime + failures + Fedu + traveltime + studytime + goout',
#  'health + famrel + Fedu + failures + traveltime + studytime + goout',
#  'health + famrel + freetime + traveltime + studytime + goout',
#  'famrel + freetime + failures + age + traveltime + goout',
#  'Medu + absences + famrel + freetime + failures + Fedu + goout',
#  'Medu + absences + Fedu + traveltime',
#  'Medu + health + absences + freetime + Fedu + failures + age + studytime + goout',
#  'health + absences + Fedu + studytime + failures + traveltime + goout',
#  'absences + Fedu + failures + age',
#  'health + absences + freetime + failures + Fedu + age',
#  'Medu + absences + Fedu + age + goout',
#  'absences + famrel + failures + Fedu + traveltime + goout',
#  'freetime + studytime + age + traveltime',
#  'Medu + health + freetime + traveltime + studytime',
#  'health + famrel + age + traveltime + studytime',
#  'Medu + health + absences + freetime + studytime + age + goout',
#  'health + famrel + freetime + Fedu + age',
#  'health + famrel + freetime + age + traveltime + goout',
#  'health + age + studytime + goout',
#  'freetime + failures + Fedu + traveltime + studytime',
#  'health + goout',
#  'Medu + health + absences + Fedu + age + studytime + goout',
#  'Medu + absences + failures + Fedu + traveltime',
#  'Medu + absences + freetime + Fedu + traveltime',
#  'Medu + failures + age + studytime',
#  'Medu + health + freetime + Fedu + age + traveltime',
#  'Medu + famrel + age + traveltime',
#  'absences + famrel + Fedu + failures + age + traveltime + studytime',
#  'Medu + health + famrel + failures + age + traveltime',
#  'health + freetime + studytime + failures + age + goout',
#  'Medu + absences + freetime + failures + Fedu + age',
#  'Medu + absences + freetime + studytime + age + goout',
#  'Medu + health + famrel + Fedu + failures + studytime + goout',
#  'absences + famrel + failures + Fedu + age',
#  'absences + famrel + Fedu + goout',
#  'Medu + absences + famrel + Fedu + failures + age + goout',
#  'freetime + Fedu + failures + age + studytime + goout',
#  'health + failures + age + studytime',
#  'absences + freetime + studytime + goout',
#  'health + age + traveltime',
#  'Medu + famrel + freetime + failures + age + traveltime + goout',
#  'health + famrel + Fedu + age + goout',
#  'Medu + health + absences + famrel + freetime + failures + studytime + goout',
#  'Medu + famrel + freetime + failures + age + goout',
#  'health + absences + famrel + failures',
#  'Medu + health + Fedu + studytime + goout',
#  'Medu + health + Fedu + failures + traveltime + goout',
#  'Medu + health + Fedu + failures',
#  'Medu + absences + Fedu + studytime + age + traveltime',
#  'Medu + health + absences + famrel + freetime + Fedu + traveltime',
#  'Medu + health + failures + studytime + goout',
#  'Medu + freetime + failures + age + studytime + goout',
#  'Medu + health + absences + famrel + freetime + failures + Fedu + age + goout',
#  'Medu + health + famrel + studytime + age + traveltime',
#  'failures + Fedu + traveltime + goout',
#  'Medu + health + absences + Fedu + studytime + age + traveltime',
#  'absences + freetime + failures + age + traveltime + goout',
#  'Medu + health + studytime + failures + goout',
#  'freetime + Fedu + age',
#  'Fedu + failures + age + goout',
#  'Medu + health + absences + freetime + failures + Fedu + studytime + goout',
#  'freetime + Fedu + age + traveltime + studytime',
#  'Medu + health + famrel + freetime + age + traveltime + goout',
#  'health + absences + famrel + freetime + age + studytime + goout',
#  'famrel',
#  'health + famrel + studytime + failures + traveltime',
#  'Medu + health + absences + famrel + failures + age + goout',
#  'famrel + Fedu + failures + studytime + goout',
#  'Medu + health + absences + freetime + age + traveltime + studytime + goout',
#  'absences + Fedu + studytime + failures + age + traveltime',
#  'absences + freetime + studytime',
#  'Medu + health + famrel + freetime + failures + Fedu + age + traveltime + studytime',
#  'Medu + freetime + Fedu + failures + age + studytime + goout',
#  'absences + famrel + freetime + age + traveltime + studytime',
#  'Medu + famrel + studytime + failures + goout',
#  'absences + famrel + traveltime + goout',
#  'Medu + health + freetime + failures + studytime',
#  'Medu + absences + Fedu + age + traveltime + studytime',
#  'absences + famrel + age + goout',
#  'health + absences + freetime + age + traveltime + studytime + goout',
#  'famrel + freetime + failures + Fedu + age + goout',
#  'Medu + health + absences + studytime',
#  'health + failures + traveltime + goout',
#  'Medu + absences + age + goout',
#  'Medu + health + freetime + Fedu + failures + traveltime',
#  'famrel + freetime + Fedu + age + studytime',
#  'health + famrel + freetime + failures + Fedu + age',
#  'health + absences + freetime + Fedu + age',
#  'health + absences + studytime + goout',
#  'Medu + health + absences + freetime + failures + Fedu + age',
#  'Medu + failures + Fedu + studytime',
#  'absences + famrel + freetime + studytime',
#  'Medu + health + absences + freetime + failures + Fedu + traveltime + goout',
#  'health + absences + Fedu + traveltime + goout',
#  'Medu + absences + failures + Fedu',
#  'Medu + health + Fedu + studytime + age + traveltime',
#  'famrel + studytime + age + goout',
#  'Medu + health + freetime + failures + Fedu + traveltime',
#  'Fedu + age + goout',
#  'health + absences + freetime + failures + Fedu + traveltime + goout',
#  'famrel + failures + Fedu + traveltime + studytime + goout',
#  'health + famrel + freetime + Fedu + traveltime + studytime + goout',
#  'Medu + absences + Fedu + age + traveltime + goout',
#  'Medu + Fedu + traveltime + studytime + goout',
#  'Medu + health + absences + freetime + failures + age + traveltime + goout',
#  'freetime + age + studytime',
#  'absences + freetime + failures + Fedu + traveltime + studytime',
#  'health + absences + famrel + freetime + failures + Fedu + traveltime + studytime + goout',
#  'absences + age + goout',
#  'health + famrel + Fedu + failures + goout',
#  'health + Fedu + failures + studytime + goout',
#  'Medu + health + absences + freetime + failures + studytime',
#  'Medu + absences + Fedu + studytime + failures + traveltime + goout',
#  'health + failures + Fedu + traveltime',
#  'Medu + Fedu + goout',
#  'famrel + studytime + failures + age + traveltime',
#  'health + famrel + freetime + age',
#  'Medu + health + absences + failures + studytime',
#  'health + absences + famrel + studytime + failures + age + goout',
#  'famrel + freetime + failures + Fedu + traveltime + studytime + goout',
#  'failures + age + goout',
#  'health + failures + Fedu + traveltime + goout',
#  'health + famrel + freetime + age + traveltime',
#  'health + absences + famrel + freetime + Fedu',
#  'absences + famrel + Fedu + age + studytime',
#  'Medu + health + absences + Fedu + studytime + failures + goout',
#  'Medu + health + absences + famrel + freetime + failures + traveltime + studytime',
#  'health + Fedu + age',
#  'Medu + health + famrel + failures + age + traveltime + studytime',
#  'absences + famrel + freetime + age + traveltime',
#  'health + absences + famrel + failures + Fedu + age + studytime',
#  'freetime + studytime + failures + age',
#  'health + famrel + freetime + age + studytime + goout',
#  'health + absences + freetime + Fedu + traveltime + goout',
#  'Medu + health + freetime + Fedu',
#  'Medu + absences + famrel + studytime + failures + goout',
#  'absences + famrel + freetime + failures + Fedu + age',
#  'Medu + absences + famrel + freetime + failures + age',
#  'freetime + failures + traveltime + studytime + goout',
#  'Medu + health + absences + famrel + failures + Fedu',
#  'Medu + health + absences + age',
#  'Medu + health + Fedu + age',
#  'Medu + absences + freetime + traveltime',
#  'health + absences + famrel + freetime + failures + age + traveltime + studytime + goout',
#  'Medu + absences + famrel + freetime + Fedu + traveltime + studytime',
#  'Medu + freetime + failures + studytime + goout',
#  'health + absences + famrel + freetime + failures + Fedu + traveltime + studytime',
#  'health + absences + famrel + studytime + traveltime',
#  'health + freetime + age + traveltime + studytime + goout',
#  'absences + Fedu + studytime + traveltime',
#  'Medu + age + traveltime',
#  'Medu + absences + freetime + traveltime + studytime + goout',
#  'health + freetime + failures + goout',
#  'health + famrel + studytime + failures + goout',
#  'Medu + absences + famrel + freetime + Fedu + age + traveltime',
#  'health + famrel + Fedu + failures + studytime + goout',
#  'absences + famrel + failures + studytime',
#  'absences + freetime + failures + Fedu + traveltime + goout',
#  'Medu + failures + age + traveltime',
#  'freetime + failures + age + studytime',
#  'absences + Fedu + age + studytime',
#  'health + absences + Fedu + studytime + failures + goout',
#  'Medu + health + absences + famrel + studytime + failures + traveltime',
#  'Medu + absences + studytime + failures + age + traveltime + goout',
#  'Medu + health + absences + Fedu + failures',
#  'famrel + freetime + failures + Fedu + age + studytime + goout',
#  'Medu + absences + famrel + freetime + studytime + goout',
#  'Medu + health + absences + famrel + freetime + Fedu + traveltime + studytime',
#  'Medu + absences + famrel + failures + goout',
#  'Medu + health + absences + Fedu + age',
#  'Medu + health + absences + Fedu + failures + age + studytime + goout',
#  'Medu + health + absences + famrel + freetime + failures + age + traveltime',
#  'Medu + absences + Fedu + studytime + failures + goout',
#  'absences + famrel + failures + age + traveltime + studytime',
#  'failures + Fedu + age + studytime',
#  'Medu + health + absences + freetime + Fedu',
#  'Medu + health + Fedu + age + traveltime + studytime + goout',
#  'health + absences + freetime + Fedu + traveltime + studytime',
#  'Medu + health + absences + freetime + studytime + failures',
#  'health + absences + famrel + freetime + failures + age + studytime + goout',
#  'famrel + failures + age + traveltime + goout',
#  'Fedu + age + traveltime + goout',
#  'health + absences + Fedu + traveltime + studytime',
#  'Medu + health + famrel + freetime + failures + Fedu',
#  'Medu + freetime + Fedu + age + goout',
#  'health + absences + freetime + failures + traveltime + goout',
#  'Medu + famrel + studytime + age',
#  'Medu + absences + Fedu + studytime + failures + age + traveltime + goout',
#  'Medu + Fedu + traveltime',
#  'Medu + health + absences + Fedu + failures + age + traveltime',
#  'Medu + famrel + freetime + failures + Fedu + age + traveltime',
#  'health + freetime + failures + age + traveltime',
#  'absences + famrel + freetime + Fedu + age',
#  'famrel + studytime + failures + traveltime',
#  'health + freetime + failures + Fedu + age + traveltime',
#  'studytime + failures + traveltime',
#  'health + freetime + Fedu',
#  'freetime + Fedu + failures + studytime',
#  'Fedu + age + traveltime + studytime + goout',
#  'Medu + famrel + freetime + traveltime + studytime',
#  'Medu + health + absences + famrel + Fedu + failures + traveltime',
#  'Medu + health + absences',
#  'freetime + failures + Fedu + age + traveltime',
#  'Medu + absences + famrel + failures + Fedu + goout',
#  'Medu + famrel + freetime + failures + traveltime + studytime + goout',
#  'absences + famrel + freetime + failures + Fedu + traveltime + studytime + goout',
#  'Medu + health + famrel + Fedu + failures + goout',
#  'Medu + famrel + freetime + Fedu + goout',
#  'health + absences + famrel + failures + Fedu + goout',
#  'Medu + health + studytime + failures + age + traveltime',
#  'Fedu + studytime + failures + age + goout',
#  'health + absences + famrel + failures + traveltime + studytime + goout',
#  'famrel + failures + Fedu + age + studytime + goout',
#  'absences + traveltime + goout',
#  'Medu + health + Fedu + age + studytime',
#  'health + absences + failures + studytime',
#  'Medu + freetime + failures',
#  'health + absences + famrel + freetime + failures + Fedu + age + traveltime + studytime + goout',
#  'health + absences + freetime + failures + Fedu + traveltime + studytime + goout',
#  'Medu + health + famrel + freetime + failures + Fedu + age + traveltime + goout',
#  'health + absences + freetime + Fedu + failures + age + studytime + goout',
#  'Medu + health + failures + Fedu + age + studytime',
#  'absences + famrel + studytime + failures + age + traveltime',
#  'Medu + famrel',
#  'Medu + health + famrel + freetime + traveltime + goout',
#  'Medu + absences + famrel + Fedu + age + traveltime',
#  'Medu + absences + failures + goout',
#  'Medu + absences + famrel + failures',
#  'Fedu + failures + traveltime + studytime + goout',
#  'Medu + health + absences + Fedu + studytime + failures',
#  'Medu + health + failures + age + studytime + goout',
#  'health + freetime + studytime + traveltime + goout',
#  'absences + Fedu + failures + studytime + goout',
#  'Medu + health + freetime + studytime + failures + age + traveltime + goout',
#  'absences + age + studytime + goout',
#  'Medu + health + absences + famrel + goout',
#  'Fedu + studytime + failures + age + traveltime',
#  'Medu + health + absences + freetime + Fedu + age',
#  'Medu + absences + famrel + Fedu + failures',
#  'Medu + famrel + age + traveltime + studytime',
#  'health + absences + freetime + studytime + failures + age + traveltime + goout',
#  'absences + freetime',
#  'Medu + health + absences + freetime + Fedu + failures + traveltime + studytime',
#  'Medu + health + absences + famrel + freetime + failures + traveltime + studytime + goout',
#  'absences + Fedu + failures + goout',
#  'health + absences + famrel + failures + Fedu + studytime + goout',
#  'health + absences + famrel + freetime',
#  'Medu + health + freetime + Fedu + failures + age',
#  'absences + freetime + studytime + failures + traveltime',
#  'freetime + studytime + failures + age + goout',
#  'famrel + freetime + traveltime + goout',
#  'absences + famrel + freetime + failures',
#  'absences + famrel',
#  'health + failures + Fedu + age',
#  'famrel + freetime + Fedu + age',
#  'Medu + health + absences + failures + Fedu + age + traveltime + goout',
#  'Medu + famrel + failures + Fedu + age + traveltime + studytime',
#  'Medu + freetime + Fedu + failures + studytime + goout',
#  'Medu + freetime + studytime + failures + goout',
#  'health + Fedu + age + traveltime + studytime',
#  'health + absences + traveltime + studytime + goout',
#  'Medu + health + absences + freetime + failures + Fedu + age + studytime + goout',
#  'Medu + absences + failures + age + traveltime + goout',
#  'Medu + health + absences + famrel + freetime + failures + Fedu + age + traveltime + goout',
#  'absences + failures + traveltime + goout',
#  'Medu + absences + famrel + Fedu + failures + age + studytime',
#  'absences + freetime + failures + goout',
#  'health + famrel + traveltime + studytime + goout',
#  'absences + famrel + freetime + Fedu + goout',
#  'health + Fedu + age + studytime',
#  'absences + Fedu + studytime + age + traveltime + goout',
#  'Medu + health + absences + Fedu + studytime + failures + age + traveltime',
#  'Medu + famrel + freetime + age + traveltime + studytime + goout',
#  'absences + freetime + failures + Fedu + age + studytime',
#  'Medu + freetime + Fedu + age + studytime',
#  'Medu + Fedu + failures + age + goout',
#  'Medu + absences + famrel + freetime + failures + age + studytime + goout',
#  'absences + freetime + Fedu + failures + age',
#  'Medu + famrel + studytime + goout',
#  'health + absences + age + traveltime + goout',
#  'absences + famrel + freetime + traveltime + goout',
#  'Medu + absences + famrel + failures + studytime',
#  'Medu + absences + famrel + failures + Fedu + age + traveltime + studytime + goout',
#  'health + absences + famrel + freetime + age + traveltime + goout',
#  'health + absences + freetime + traveltime + goout',
#  'Medu + health + traveltime + goout',
#  'Medu + absences + Fedu + failures + age + traveltime + studytime + goout',
#  'Medu + health + famrel + freetime + failures + age + traveltime',
#  'Medu + famrel + freetime + failures + Fedu + age + traveltime + studytime + goout',
#  'absences + famrel + age',
#  'Medu + health + famrel + studytime + age + goout',
#  'health + freetime + Fedu + failures + traveltime + studytime',
#  'Medu + health + absences + famrel + freetime + failures + Fedu',
#  'Medu + health + famrel + freetime + failures + Fedu + goout',
#  'Medu + health + absences + Fedu + studytime + age + goout',
#  'Medu + absences + famrel + freetime',
#  'Medu + health + famrel + studytime + failures + age',
#  'health + absences + freetime + failures + Fedu + age + studytime + goout',
#  'health + absences + famrel + failures + traveltime',
#  'absences + studytime + goout',
#  'health + freetime + studytime + failures',
#  'Medu + famrel + studytime + age + traveltime',
#  'health + absences + Fedu + age + studytime + goout',
#  'Medu + absences + freetime + failures + Fedu + traveltime + goout',
#  'Medu + health + Fedu + failures + traveltime',
#  'health + absences + famrel + freetime + Fedu + age + traveltime + studytime',
#  'Medu + health + absences + studytime + age + traveltime',
#  'absences + famrel + freetime + failures + Fedu + age + traveltime + studytime',
#  'Medu + absences + famrel + Fedu + age + studytime',
#  'freetime + failures + traveltime',
#  'Medu + famrel + freetime + Fedu + traveltime',
#  'Medu + famrel + Fedu + failures + age',
#  'absences + failures + traveltime + studytime + goout',
#  'Medu + health + studytime',
#  'Medu + absences + famrel + failures + Fedu + age + traveltime',
#  'Medu + famrel + studytime + age + traveltime + goout',
#  'Medu + absences + freetime + failures + Fedu + age + traveltime',
#  'Medu + traveltime',
#  'Medu + absences + Fedu + failures + traveltime + studytime',
#  'famrel + freetime',
#  'Medu + absences + freetime + failures + Fedu + studytime',
#  'famrel + age',
#  'famrel + freetime + Fedu + traveltime',
#  'Medu + health + famrel + failures + Fedu + traveltime + goout',
#  'Medu + health + famrel + Fedu + traveltime + studytime',
#  'Medu + health + famrel + freetime + failures + studytime',
#  'health + absences + famrel + Fedu + failures + age + studytime',
#  'absences + famrel + failures + traveltime + studytime',
#  'Medu + health + absences + famrel + freetime + failures + Fedu + age + traveltime',
#  'Medu + absences + famrel + failures + Fedu + age + studytime + goout',
#  'famrel + freetime + Fedu + traveltime + studytime',
#  'health + Fedu + failures + goout',
#  'Medu + absences + Fedu + studytime + traveltime + goout',
#  'Medu + famrel + Fedu + studytime + goout',
#  'Fedu + studytime + traveltime',
#  'health + absences + freetime + studytime + failures + age',
#  'Medu + health + absences + freetime + failures + Fedu + age + traveltime',
#  'Medu + health + famrel + age + traveltime + studytime',
#  'Medu + health + absences + famrel + failures + Fedu + age + traveltime + goout',
#  'health + absences + famrel + freetime + Fedu + traveltime',
#  'health + famrel + freetime + failures + Fedu',
#  'Medu + health + absences + famrel + failures + Fedu + age + traveltime + studytime + goout',
#  'Fedu + studytime + age + goout',
#  'famrel + failures + age + studytime',
#  'famrel + freetime + failures + studytime',
#  'Medu + Fedu + age + traveltime + goout',
#  'Medu + famrel + freetime + failures + traveltime',
#  'Medu + absences + freetime + studytime + failures + age + traveltime',
#  'health + absences + famrel + Fedu + traveltime + studytime',
#  'famrel + freetime + failures + age + traveltime',
#  'Medu + health + famrel + studytime + failures',
#  'Medu + absences + famrel + freetime + age + traveltime',
#  'Medu + health + Fedu + traveltime + goout',
#  'Medu + health + failures + age + traveltime',
#  'Medu + health + absences + famrel + traveltime + goout',
#  'Medu + freetime + traveltime + studytime + goout',
#  'Medu + freetime + Fedu + failures + traveltime',
#  'Medu + health + absences + Fedu + failures + traveltime + studytime + goout',
#  'Medu + health + freetime + Fedu + studytime',
#  'studytime + failures + age',
#  'famrel + Fedu + failures + age + goout',
#  'Medu + absences + freetime + studytime + goout',
#  'Medu + health + absences + famrel + freetime + failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + freetime',
#  'famrel + Fedu + goout',
#  'Medu + age + traveltime + goout',
#  'Medu + absences + freetime + failures + age + traveltime + studytime + goout',
#  'Medu + health + famrel + freetime + age + traveltime',
#  'Medu + famrel + freetime + failures + Fedu + studytime',
#  'freetime + failures + Fedu + age + traveltime + goout',
#  'Medu + freetime + age + goout',
#  'health + absences + famrel + Fedu + failures + traveltime + goout',
#  'traveltime + studytime + goout',
#  'Medu + health + absences + famrel + freetime + age + goout',
#  'Medu + Fedu + studytime + failures',
#  'Medu + famrel + freetime + studytime',
#  'health + studytime + failures',
#  'Medu + health + famrel + freetime + Fedu + age + studytime + goout',
#  'Medu + absences + famrel + freetime + traveltime',
#  'Medu + health + failures + Fedu + age + traveltime',
#  'Medu + absences + famrel + freetime + age + studytime',
#  'health + absences + famrel + failures + age + studytime',
#  'health + absences + famrel + failures + age + goout',
#  'health + freetime + traveltime',
#  'famrel + failures + age + studytime + goout',
#  'health + freetime + studytime + age + goout',
#  'famrel + failures + Fedu + studytime + goout',
#  'Medu + health + absences + famrel + failures + studytime',
#  'Medu + absences + Fedu + failures + age + traveltime',
#  'Medu + absences + freetime + Fedu + failures + studytime',
#  'Medu + absences + freetime + Fedu + age + studytime + goout',
#  'health + famrel + failures + age + traveltime + studytime + goout',
#  'freetime + Fedu + age + studytime + goout',
#  'Medu + health + famrel + failures + Fedu + traveltime + studytime',
#  'health + failures + studytime + goout',
#  'absences + studytime + failures + traveltime',
#  'health + famrel + freetime + failures + Fedu + age + traveltime',
#  'health + famrel + freetime + Fedu',
#  'Medu + famrel + freetime + failures + age + traveltime',
#  'famrel + freetime + Fedu + traveltime + goout',
#  'Medu + studytime + age',
#  'Medu + absences + freetime + Fedu + age + studytime',
#  'health + absences + freetime + failures + age + traveltime + studytime',
#  'Medu + health + absences + famrel + Fedu + failures + studytime + goout',
#  'Medu + absences + famrel + freetime + failures + Fedu + age + goout',
#  'Medu + absences + Fedu + age + studytime',
#  'Medu + Fedu + studytime + failures + age + traveltime + goout',
#  'health + absences + freetime + studytime + failures + traveltime',
#  'Medu + health + famrel + freetime + age + traveltime + studytime',
#  'health + famrel + age',
#  'absences + famrel + Fedu + failures + age + studytime + goout',
#  'famrel + freetime + Fedu + studytime + goout',
#  'absences + famrel + Fedu + studytime',
#  'Fedu + failures + studytime',
#  'health + famrel + Fedu + age + traveltime + goout',
#  'health + absences + studytime + failures + age',
#  'absences + studytime + failures + age + goout',
#  'Medu + health + famrel + failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + health + freetime + Fedu + failures + traveltime + studytime',
#  'Medu + health + famrel + Fedu + goout',
#  'health + freetime + Fedu + age + traveltime + goout',
#  'health + studytime + age',
#  'Medu + health + absences + famrel + Fedu + age + studytime',
#  'health + absences + freetime + Fedu + failures + studytime + goout',
#  'Fedu + studytime',
#  'Medu + health + absences + freetime + Fedu + failures + age + traveltime',
#  'Medu + health + famrel + failures + Fedu + traveltime + studytime + goout',
#  'health + famrel + traveltime + goout',
#  'famrel + age + studytime + goout',
#  'Medu + health + absences + famrel + Fedu + failures',
#  'Medu + health + freetime + age + studytime + goout',
#  'studytime + traveltime',
#  'Medu + absences + famrel + failures + age + goout',
#  'famrel + studytime + traveltime + goout',
#  'Medu + absences + famrel + traveltime + goout',
#  'health + famrel + freetime + failures + age + goout',
#  'Medu + absences + freetime + failures + age',
#  'Medu + famrel + Fedu + failures + age + traveltime + studytime + goout',
#  'Medu + absences + freetime + studytime + failures + age',
#  'health + freetime + failures + Fedu + studytime',
#  'absences + Fedu + age + traveltime',
#  'freetime + failures + Fedu + age + studytime',
#  'Medu + famrel + Fedu + studytime',
#  'freetime + failures + Fedu + goout',
#  'famrel + freetime + Fedu + age + traveltime + studytime',
#  'health + absences + famrel + failures + traveltime + goout',
#  'health + studytime + failures + age + goout',
#  'Medu + famrel + freetime + Fedu + age',
#  'health + absences + Fedu + traveltime + studytime + goout',
#  'health + absences + Fedu + studytime + age + traveltime + goout',
#  'Medu + absences + freetime + studytime',
#  'Medu + absences + famrel + freetime + Fedu + goout',
#  'Medu + freetime + Fedu',
#  'Medu + failures + Fedu + goout',
#  'Medu + health + absences + studytime + age + traveltime + goout',
#  'Medu + health + absences + famrel + freetime + traveltime + studytime',
#  'health + absences + famrel + age + goout',
#  'Medu + absences + failures + traveltime + studytime + goout',
#  'Medu + absences + freetime + failures + age + traveltime + studytime',
#  'Medu + health + absences + famrel + freetime + Fedu + age + traveltime + goout',
#  'Medu + Fedu + age + studytime',
#  'Medu + absences + freetime + failures + Fedu + age + studytime',
#  'Medu + health + famrel + studytime + traveltime',
#  'absences + famrel + freetime + failures + Fedu',
#  'Medu + absences + freetime + failures + Fedu + age + studytime + goout',
#  'absences + freetime + failures + Fedu + age',
#  'health + failures + Fedu + studytime',
#  'Medu + health + famrel + Fedu + failures + traveltime + goout',
#  'absences + studytime + failures + traveltime + goout',
#  'health + absences + Fedu + failures + age + goout',
#  'absences + failures + studytime + goout',
#  'absences + famrel + freetime + failures + age + traveltime + studytime',
#  'Medu + health + absences + famrel + freetime',
#  'Medu + absences + failures + studytime',
#  'health + absences + famrel + freetime + failures + Fedu + age + traveltime + studytime',
#  'Medu + absences + famrel + age + traveltime',
#  'Medu + health + absences + famrel + failures + Fedu + age + studytime',
#  'freetime + failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + health + freetime + failures + traveltime + studytime + goout',
#  'Fedu + traveltime',
#  'health + famrel + failures + studytime',
#  'studytime + traveltime + goout',
#  'health + freetime + goout',
#  'Medu + health + famrel + freetime + Fedu + goout',
#  'Medu + absences + famrel + freetime + failures + traveltime + studytime + goout',
#  'Medu + health + absences + famrel + freetime + failures + Fedu + age + studytime + goout',
#  'absences + failures + Fedu + traveltime + studytime',
#  'health + absences + famrel + failures + Fedu + age + traveltime',
#  'Medu + absences + famrel + failures + Fedu + traveltime',
#  'Medu + absences + failures + Fedu + traveltime + goout',
#  'health + studytime + failures + age',
#  'Medu + health + Fedu + studytime + traveltime + goout',
#  'Medu + freetime + Fedu + failures',
#  'health + absences + failures + studytime + goout',
#  'Medu + famrel + failures + age',
#  'absences + freetime + failures + age',
#  'Medu + health + absences + traveltime + studytime',
#  'Medu + failures',
#  'famrel + freetime + failures + age + studytime',
#  'Medu + health + absences + famrel + freetime + failures + Fedu + traveltime + studytime + goout',
#  'famrel + traveltime',
#  'health + famrel + failures + Fedu + traveltime + studytime',
#  'health + absences + famrel + studytime + failures + goout',
#  'Medu + absences + freetime + failures + age + studytime',
#  'Medu + health + freetime + failures + Fedu',
#  'Medu + health + goout',
#  'Medu + health + absences + studytime + age',
#  'Medu + absences + famrel + freetime + age + traveltime + studytime + goout',
#  'Medu + health + absences + freetime + goout',
#  'Medu + health + absences + freetime + failures + age + studytime + goout',
#  'Medu + absences + famrel + freetime + failures + age + goout',
#  'absences + famrel + freetime + failures + Fedu + traveltime + studytime',
#  'Medu + Fedu + failures + age + traveltime + goout',
#  'absences + famrel + freetime + Fedu + age + traveltime + studytime',
#  'Medu + health + freetime + goout',
#  'health + absences + famrel + failures + age + traveltime',
#  'absences + failures + Fedu',
#  'Medu + age + studytime',
#  'Medu + health + famrel + freetime + Fedu + traveltime + goout',
#  'health + famrel + failures + traveltime',
#  'famrel + freetime + age + studytime',
#  'Medu + absences + famrel + freetime + failures + traveltime',
#  'freetime + failures + age + traveltime + studytime',
#  'absences + freetime + Fedu + failures',
#  'Medu + absences + famrel + Fedu + failures + age + traveltime',
#  'failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + famrel + Fedu + failures + traveltime + studytime',
#  'Medu + health + studytime + traveltime',
#  'Medu + Fedu + traveltime + goout',
#  'Medu + famrel + freetime + failures + goout',
#  'health + failures + traveltime + studytime + goout',
#  'Medu + absences + famrel + failures + age + studytime',
#  'Medu + health + absences + freetime + Fedu + traveltime + studytime',
#  'Medu + health + absences + studytime + failures + age + traveltime + goout',
#  'health + absences + freetime + failures + goout',
#  'Medu + health + absences + famrel + Fedu + failures + traveltime + goout',
#  'Medu + age + goout',
#  'health + absences + freetime + studytime + goout',
#  'Medu + absences + failures + Fedu + studytime + goout',
#  'health + freetime + studytime + failures + traveltime + goout',
#  'Fedu + failures + age + traveltime',
#  'Medu + absences + failures + age + goout',
#  'Medu + absences + freetime + Fedu + traveltime + goout',
#  'Medu + health + famrel + failures + studytime',
#  'health + famrel + freetime + age + studytime',
#  'health + absences + failures + age + traveltime',
#  'Medu + health + Fedu + failures + age + traveltime + studytime + goout',
#  'health + famrel + studytime + traveltime + goout',
#  'famrel + Fedu + failures',
#  'health + absences + famrel + Fedu + traveltime',
#  'Medu + health + absences + famrel + age + traveltime',
#  'Medu + health + absences + failures + age + studytime + goout',
#  'Medu + absences + freetime + age',
#  'Medu + Fedu + age + traveltime + studytime + goout',
#  'health + absences + famrel + Fedu + traveltime + goout',
#  'absences + freetime + failures + age + traveltime + studytime',
#  'Medu + health + famrel + freetime + failures + Fedu + studytime + goout',
#  'Medu + absences + famrel + studytime + failures + age + traveltime + goout',
#  'freetime + Fedu + studytime',
#  'freetime + age + traveltime',
#  'Medu + health + absences + freetime + Fedu + failures + traveltime',
#  'Medu + famrel + freetime + failures + Fedu + age + studytime',
#  'absences + famrel + failures + traveltime + goout',
#  'Fedu + failures + studytime + goout',
#  'health + famrel + Fedu + failures + age + traveltime + studytime',
#  'studytime + failures',
#  'Medu + health + studytime + age + traveltime',
#  'Fedu + studytime + failures + age',
#  'absences + freetime + failures + Fedu + goout',
#  'freetime + studytime + age',
#  'health + absences + famrel + freetime + failures + age + goout',
#  'Medu + absences + failures + Fedu + age + traveltime + studytime + goout',
#  'absences + famrel + freetime + failures + Fedu + age + traveltime + goout',
#  'health + famrel + Fedu + failures + age + studytime',
#  'Medu + absences + famrel + failures + Fedu + traveltime + studytime + goout',
#  'Medu + health + freetime + Fedu + studytime + goout',
#  'health + famrel + age + traveltime',
#  'Medu + health + absences + famrel + studytime + goout',
#  'Medu + absences + famrel + freetime + Fedu + traveltime + studytime + goout',
#  'health + famrel + failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + absences + failures + age + traveltime + studytime',
#  'Medu + health + absences + famrel + Fedu + failures + age + studytime + goout',
#  'health + Fedu + studytime + failures + age + traveltime',
#  'Medu + health + famrel + freetime + failures + traveltime + goout',
#  'Medu + health + Fedu + studytime',
#  'absences + famrel + Fedu + failures + age',
#  'absences + studytime + failures + age + traveltime',
#  'Medu + health + freetime + age + traveltime + studytime',
#  'Medu + health + absences + Fedu + failures + age',
#  'health + absences + famrel + Fedu + failures + studytime + goout',
#  'health + famrel + Fedu + failures + age + traveltime + studytime + goout',
#  'Medu + health + absences + freetime',
#  'absences + famrel + freetime + failures + Fedu + age + traveltime',
#  'health + absences + Fedu + age + traveltime + studytime',
#  'Medu + absences + famrel + Fedu + failures + goout',
#  'famrel + failures + age',
#  'Medu + famrel + Fedu + failures',
#  'absences + famrel + freetime + Fedu + age + studytime',
#  'Medu + famrel + Fedu + age + traveltime + studytime',
#  'Medu + health + absences + freetime + Fedu + failures + age',
#  'absences + famrel + failures + traveltime',
#  'health + absences + freetime + Fedu + failures + age + traveltime + goout',
#  'absences + famrel + failures + age + traveltime',
#  'health + Fedu + traveltime + goout',
#  'health + absences + failures + traveltime + studytime',
#  'Medu + absences + Fedu + failures + studytime',
#  'health + absences + freetime + failures + age + traveltime + goout',
#  'Medu + freetime + failures + age + traveltime + goout',
#  'Medu + health + studytime + failures + age + traveltime + goout',
#  'Medu + health + absences + famrel + traveltime + studytime',
#  'Medu + famrel + freetime + failures + Fedu + age + traveltime + goout',
#  'health + absences + famrel + failures + age + studytime + goout',
#  'Medu + freetime + age',
#  'health + absences + freetime + Fedu + failures + age + traveltime + studytime',
#  'Medu + health + absences + famrel + freetime + traveltime + goout',
#  'Medu + health + famrel + Fedu + age + goout',
#  'Medu + freetime + failures + Fedu + age + studytime + goout',
#  'Medu + absences + famrel + freetime + failures + Fedu',
#  'health + absences + famrel + freetime + traveltime',
#  'absences + famrel + traveltime + studytime',
#  'absences + freetime + failures + studytime',
#  'Medu + health + freetime + studytime + failures + traveltime',
#  'Medu + absences + freetime + age + traveltime',
#  'Medu + health + studytime + age + goout',
#  'health + famrel + age + traveltime + goout',
#  'absences + famrel + freetime + failures + Fedu + age + studytime + goout',
#  'Medu + health + absences + freetime + failures + age',
#  'health + freetime + studytime + age + traveltime',
#  'Medu + health + famrel + Fedu + failures + age + traveltime + goout',
#  'health + famrel + freetime + failures + Fedu + traveltime + studytime + goout',
#  'Medu + health + Fedu + age + studytime + goout',
#  'health + freetime',
#  'freetime + traveltime + studytime',
#  'health + failures + age + studytime + goout',
#  'absences + famrel + Fedu + failures + age + traveltime + studytime + goout',
#  'health + absences + famrel + failures + Fedu + age',
#  'Medu + health + traveltime + studytime',
#  'health + famrel + failures + age',
#  'Medu + freetime + failures + Fedu + age + traveltime',
#  'health + Fedu',
#  'Medu + health + Fedu + failures + age + studytime + goout',
#  'health + absences + freetime + failures + Fedu + traveltime + studytime',
#  'health + absences + famrel + Fedu + failures + studytime',
#  'health + absences + famrel + Fedu + failures + age + goout',
#  'Medu + absences + famrel + freetime + age',
#  'health + absences + famrel + freetime + age + traveltime + studytime',
#  'health + freetime + Fedu + failures + studytime',
#  'absences + famrel + Fedu + failures + traveltime + studytime + goout',
#  'health + absences + famrel + freetime + traveltime + studytime',
#  'health + absences + famrel + Fedu + studytime + goout',
#  'Medu + health + absences + famrel + freetime + Fedu + studytime',
#  'Medu + health + famrel + Fedu + age + traveltime + goout',
#  'Medu + health + absences + Fedu + failures + age + traveltime + studytime + goout',
#  'freetime + Fedu',
#  'health + famrel + freetime + traveltime',
#  'absences + traveltime',
#  'absences + famrel + Fedu + failures + studytime',
#  'health + famrel + age + traveltime + studytime + goout',
#  'famrel + freetime + traveltime + studytime + goout',
#  'Medu + famrel + Fedu',
#  'Medu + health + absences + famrel + Fedu + failures + age + studytime',
#  'health + freetime + Fedu + failures + age + traveltime + studytime + goout',
#  'freetime + traveltime + studytime + goout',
#  'Fedu + failures + age + traveltime + studytime',
#  'Medu + famrel + failures + traveltime',
#  'health + absences + freetime + studytime + age + goout',
#  'Medu + health + freetime + studytime + failures + traveltime + goout',
#  'health + absences + famrel + failures + Fedu + age + traveltime + studytime',
#  'absences + famrel + freetime + failures + age + traveltime + goout',
#  'absences + Fedu + failures + age + traveltime',
#  'Medu + health + famrel + freetime + failures + Fedu + studytime',
#  'health + Fedu + failures + age + traveltime + studytime + goout',
#  'health + absences + famrel + Fedu + age + traveltime + studytime',
#  'Medu + freetime + failures + Fedu',
#  'Medu + health + absences + famrel + studytime + age + goout',
#  'absences + Fedu + studytime + age + traveltime',
#  'Medu + health + absences + famrel + freetime + failures + age + studytime + goout',
#  'health + absences + Fedu + age + goout',
#  'Medu + absences + famrel + freetime + age + traveltime + goout',
#  'Medu + failures + traveltime + studytime + goout',
#  'health + failures + age + traveltime + goout',
#  'health + absences + Fedu + studytime + traveltime + goout',
#  'health + absences + famrel + failures + age + traveltime + studytime',
#  'studytime + failures + traveltime + goout',
#  'Medu + freetime + studytime + age + traveltime + goout',
#  'health + Fedu + age + goout',
#  'Medu + absences + Fedu + failures + age + traveltime + goout',
#  'Medu + health + famrel + studytime + goout',
#  'health + absences + famrel + studytime + age + traveltime + goout',
#  'health + absences + freetime + failures + Fedu + age + traveltime + goout',
#  'Medu + Fedu + failures + age + studytime',
#  'Medu + health + freetime + traveltime',
#  'Medu + health + Fedu + age + traveltime + goout',
#  'Medu + absences + freetime + failures + Fedu + age + traveltime + goout',
#  'Medu + absences + freetime + Fedu',
#  'health + absences + famrel + freetime + failures + Fedu',
#  'Medu + absences + famrel + freetime + Fedu + studytime',
#  'Medu + health + famrel + freetime + failures + Fedu + age + studytime + goout',
#  'Medu + health + absences + famrel + failures + Fedu + age + traveltime + studytime',
#  'health + famrel + age + studytime + goout',
#  'absences + freetime + failures + traveltime + goout',
#  'absences + freetime + Fedu + failures + traveltime',
#  'freetime + Fedu + failures + age',
#  'Medu + health + failures + age + studytime',
#  'health + famrel + freetime + Fedu + age + traveltime + studytime',
#  'Medu + health + absences + famrel + freetime + failures + age + studytime',
#  'Medu + failures + Fedu + traveltime',
#  'health + failures + Fedu + age + traveltime + goout',
#  'Medu + health + absences + Fedu + studytime + failures + traveltime',
#  'health + absences + freetime + failures + Fedu + age + traveltime + studytime',
#  'absences + freetime + traveltime + studytime + goout',
#  'Medu + absences + freetime + failures + traveltime',
#  'Medu + health + absences + Fedu + studytime + failures + traveltime + goout',
#  'Medu + freetime + studytime + failures + traveltime',
#  'studytime + failures + age + traveltime',
#  'Medu + Fedu + failures + age + traveltime + studytime',
#  'Medu + Fedu + studytime + traveltime',
#  'famrel + freetime + failures + Fedu + goout',
#  'Medu + freetime + Fedu + studytime + goout',
#  'Medu + absences + famrel + Fedu + studytime + goout',
#  'Medu + absences + famrel + studytime + goout',
#  'Medu + health + absences + freetime + Fedu + age + goout',
#  'failures + studytime + goout',
#  'Medu + absences + freetime',
#  'Fedu + studytime + failures + traveltime + goout',
#  'Medu + health + famrel + freetime + failures + Fedu + traveltime + studytime',
#  'Medu + health + freetime + Fedu + failures + age + traveltime + studytime',
#  'Medu + absences + age',
#  'Medu + health + freetime + failures + traveltime + goout',
#  'absences + studytime',
#  'absences + freetime + Fedu',
#  'famrel + failures + Fedu + traveltime',
#  'absences + Fedu + studytime + failures + goout',
#  'absences + famrel + age + studytime',
#  'Medu + health + famrel + Fedu + failures',
#  'Medu + health + age + traveltime + goout',
#  'health + freetime + failures + age + goout',
#  'Medu + health + absences + famrel + freetime + failures + traveltime + goout',
#  'Medu + health + absences + failures + Fedu + age + studytime + goout',
#  'Medu + absences + Fedu + traveltime + studytime',
#  'health + freetime + traveltime + goout',
#  'health + famrel + freetime + age + traveltime + studytime + goout',
#  'studytime + goout',
#  'health + freetime + age + traveltime + goout',
#  'health + absences + Fedu + age + studytime',
#  'Medu + health + famrel + Fedu + failures + traveltime + studytime',
#  'Medu + failures + age + goout',
#  'health + freetime + failures + age + traveltime + goout',
#  'health + absences + famrel + studytime + failures + traveltime',
#  'Medu + health + freetime + traveltime + studytime + goout',
#  'Medu + health + famrel + freetime + failures + Fedu + age + traveltime + studytime + goout',
#  'Medu + health + freetime + Fedu + failures + age + traveltime',
#  'health + famrel + failures + Fedu + age + traveltime + studytime',
#  'Medu + health + freetime + failures + age + traveltime + goout',
#  'Medu + studytime + failures + traveltime',
#  'absences + famrel + failures + Fedu + studytime',
#  'Medu + health + absences + famrel + freetime + Fedu + age + traveltime + studytime + goout',
#  'Medu + health + famrel + freetime + failures + traveltime',
#  'Medu + health',
#  'Medu + Fedu + failures + traveltime + studytime + goout',
#  'absences + famrel + failures + age + traveltime + studytime + goout',
#  'failures + Fedu + traveltime + studytime + goout',
#  'health + failures + age',
#  ...}

# %%
results = {}

# Посчитаем Adjusted R-Squared для каждого сочетания признаков
for variable_set in bruteforce_variables:
    lin_model = sm.ols(formula = 'score ~ ' + variable_set, data = df).fit()
    results[variable_set] = f'{lin_model.rsquared_adj:.3}'
    
# Выведем отсортированные результаты 
vrbls_R_squared_set = sorted(results.items(), key = lambda x: x[1], reverse = True)
for elem in vrbls_R_squared_set:
    print(elem[1], '\t', elem[0])
# Out:
# 0.157 	 studytime + goout + failures + traveltime + absences + Medu
# 0.157 	 studytime + goout + traveltime + failures + absences + Medu
# 0.157 	 studytime + goout + failures + absences + traveltime + Medu
# 0.155 	 studytime + goout + Fedu + failures + traveltime + absences + Medu
# 0.155 	 studytime + goout + Fedu + traveltime + failures + absences + Medu
# 0.153 	 studytime + goout + famrel + failures + traveltime + absences + Medu
# 0.153 	 studytime + goout + age + traveltime + failures + absences + Medu
# 0.153 	 studytime + goout + famrel + failures + absences + traveltime + Medu
# 0.153 	 studytime + goout + age + failures + traveltime + absences + Medu
# 0.153 	 studytime + goout + famrel + traveltime + failures + absences + Medu
# 0.152 	 studytime + goout + famrel + Fedu + failures + traveltime + absences + Medu
# 0.152 	 studytime + goout + famrel + Fedu + traveltime + failures + absences + Medu
# 0.152 	 studytime + goout + Fedu + age + traveltime + failures + absences + Medu
# 0.151 	 goout + traveltime + failures + absences + Medu
# 0.151 	 studytime + goout + failures + absences + traveltime + Medu + freetime
# 0.151 	 studytime + goout + failures + traveltime + absences + freetime + Medu
# 0.151 	 studytime + goout + failures + freetime + traveltime + absences + Medu
# 0.151 	 studytime + goout + traveltime + failures + freetime + absences + Medu
# 0.151 	 studytime + goout + failures + absences + traveltime + freetime + Medu
# 0.151 	 studytime + goout + failures + traveltime + freetime + absences + Medu
# 0.151 	 goout + failures + absences + traveltime + Medu
# 0.151 	 goout + failures + traveltime + absences + Medu
# 0.15 	 goout + Fedu + failures + traveltime + absences + Medu
# 0.15 	 goout + failures + traveltime + freetime + absences + Medu
# 0.15 	 goout + Fedu + traveltime + failures + absences + Medu
# 0.15 	 goout + failures + absences + traveltime + Medu + freetime
# 0.15 	 studytime + goout + Fedu + failures + traveltime + absences + freetime + Medu
# 0.15 	 goout + failures + traveltime + absences + freetime + Medu
# 0.15 	 studytime + goout + famrel + age + failures + traveltime + absences + Medu
# 0.15 	 goout + failures + freetime + traveltime + absences + Medu
# 0.15 	 studytime + goout + Fedu + failures + traveltime + freetime + absences + Medu
# 0.15 	 studytime + goout + Fedu + traveltime + failures + freetime + absences + Medu
# 0.15 	 studytime + goout + famrel + age + traveltime + failures + absences + Medu
# 0.15 	 goout + traveltime + failures + freetime + absences + Medu
# 0.15 	 goout + failures + absences + traveltime + freetime + Medu
# 0.149 	 goout + Fedu + failures + traveltime + freetime + absences + Medu
# 0.149 	 goout + Fedu + traveltime + failures + freetime + absences + Medu
# 0.149 	 studytime + goout + famrel + Fedu + age + traveltime + failures + absences + Medu
# 0.149 	 goout + Fedu + failures + traveltime + absences + freetime + Medu
# 0.148 	 goout + famrel + traveltime + failures + absences + Medu
# 0.148 	 goout + age + traveltime + failures + absences + Medu
# 0.148 	 studytime + goout + famrel + failures + absences + traveltime + Medu + freetime
# 0.148 	 studytime + goout + famrel + traveltime + failures + freetime + absences + Medu
# 0.148 	 studytime + goout + famrel + failures + traveltime + absences + freetime + Medu
# 0.148 	 goout + famrel + failures + traveltime + absences + Medu
# 0.148 	 goout + famrel + failures + absences + traveltime + Medu
# 0.148 	 studytime + goout + age + failures + freetime + traveltime + absences + Medu
# 0.148 	 studytime + goout + age + traveltime + failures + freetime + absences + Medu
# 0.148 	 studytime + goout + failures + absences + Medu
# 0.148 	 studytime + goout + famrel + failures + traveltime + freetime + absences + Medu
# 0.148 	 studytime + goout + famrel + failures + freetime + traveltime + absences + Medu
# 0.148 	 studytime + goout + famrel + failures + absences + traveltime + freetime + Medu
# 0.148 	 goout + age + failures + traveltime + absences + Medu
# 0.147 	 goout + famrel + failures + absences + traveltime + freetime + Medu
# 0.147 	 goout + famrel + Fedu + traveltime + failures + absences + Medu
# 0.147 	 goout + famrel + traveltime + failures + freetime + absences + Medu
# 0.147 	 goout + famrel + Fedu + failures + traveltime + absences + Medu
# 0.147 	 goout + famrel + failures + traveltime + freetime + absences + Medu
# 0.147 	 goout + Fedu + age + traveltime + failures + absences + Medu
# 0.147 	 goout + famrel + failures + traveltime + absences + freetime + Medu
# 0.147 	 goout + famrel + failures + freetime + traveltime + absences + Medu
# 0.147 	 goout + age + failures + freetime + traveltime + absences + Medu
# 0.147 	 goout + age + traveltime + failures + freetime + absences + Medu
# 0.147 	 goout + famrel + failures + absences + traveltime + Medu + freetime
# 0.146 	 goout + famrel + Fedu + failures + traveltime + freetime + absences + Medu
# 0.146 	 goout + famrel + Fedu + failures + traveltime + absences + freetime + Medu
# 0.146 	 goout + famrel + Fedu + traveltime + failures + freetime + absences + Medu
# 0.146 	 studytime + goout + famrel + Fedu + traveltime + failures + freetime + absences + Medu
# 0.146 	 studytime + goout + famrel + Fedu + failures + traveltime + absences + freetime + Medu
# 0.146 	 studytime + goout + Fedu + age + traveltime + failures + freetime + absences + Medu
# 0.146 	 studytime + goout + famrel + Fedu + failures + traveltime + freetime + absences + Medu
# 0.145 	 goout + Fedu + age + traveltime + failures + freetime + absences + Medu
# 0.145 	 goout + famrel + age + traveltime + failures + absences + Medu
# 0.145 	 studytime + goout + famrel + failures + absences + Medu
# 0.145 	 goout + famrel + age + failures + traveltime + absences + Medu
# 0.145 	 studytime + goout + age + failures + absences + Medu
# 0.145 	 studytime + goout + Fedu + failures + absences + Medu
# 0.144 	 studytime + goout + famrel + age + traveltime + failures + freetime + absences + Medu
# 0.144 	 studytime + goout + famrel + age + failures + freetime + traveltime + absences + Medu
# 0.144 	 goout + famrel + Fedu + age + traveltime + failures + absences + Medu
# 0.143 	 studytime + goout + famrel + Fedu + age + traveltime + failures + freetime + absences + Medu
# 0.143 	 goout + famrel + age + traveltime + failures + freetime + absences + Medu
# 0.143 	 goout + famrel + age + failures + freetime + traveltime + absences + Medu
# 0.142 	 studytime + goout + failures + traveltime + Medu
# 0.142 	 studytime + goout + famrel + age + failures + absences + Medu
# 0.142 	 goout + famrel + Fedu + age + traveltime + failures + freetime + absences + Medu
# 0.142 	 studytime + goout + failures + Medu + traveltime
# 0.142 	 studytime + goout + traveltime + failures + Medu
# 0.142 	 studytime + goout + Fedu + age + failures + absences + Medu
# 0.142 	 studytime + goout + famrel + Fedu + failures + absences + Medu
# 0.141 	 studytime + goout + Fedu + traveltime + failures + health + absences + Medu
# 0.141 	 studytime + goout + Fedu + failures + traveltime + health + absences + Medu
# 0.141 	 studytime + goout + Fedu + traveltime + failures + Medu
# 0.141 	 studytime + goout + Fedu + failures + traveltime + Medu
# 0.14 	 studytime + goout + failures + absences + traveltime
# 0.14 	 studytime + goout + traveltime + failures + health + absences + Medu
# 0.14 	 studytime + goout + failures + absences + traveltime + health + Medu
# 0.14 	 studytime + goout + failures + traveltime + health + absences + Medu
# 0.14 	 studytime + goout + traveltime + failures + absences
# 0.14 	 studytime + goout + failures + traveltime + absences
# 0.139 	 studytime + goout + famrel + traveltime + failures + Medu
# 0.139 	 studytime + goout + famrel + failures + Medu + traveltime
# 0.139 	 studytime + goout + Fedu + traveltime + failures + absences
# 0.139 	 studytime + goout + Fedu + failures + traveltime + absences
# 0.139 	 studytime + goout + famrel + Fedu + age + failures + absences + Medu
# 0.139 	 studytime + goout + famrel + failures + traveltime + Medu
# 0.138 	 studytime + goout + freetime + failures + absences + Medu
# 0.138 	 studytime + goout + famrel + Fedu + failures + traveltime + Medu
# 0.138 	 studytime + goout + famrel + Fedu + traveltime + failures + Medu
# 0.138 	 studytime + goout + age + traveltime + failures + Medu
# 0.138 	 studytime + goout + failures + freetime + absences + Medu
# 0.138 	 studytime + goout + failures + absences + freetime + Medu
# 0.138 	 studytime + goout + age + failures + traveltime + Medu
# 0.138 	 studytime + goout + failures + absences + Medu + freetime
# 0.137 	 studytime + goout + famrel + failures + absences + traveltime
# 0.137 	 studytime + goout + famrel + Fedu + traveltime + failures + health + absences + Medu
# 0.137 	 studytime + goout + famrel + failures + traveltime + health + absences + Medu
# 0.137 	 studytime + goout + age + failures + traveltime + absences
# 0.137 	 studytime + goout + famrel + traveltime + failures + absences
# 0.137 	 studytime + goout + famrel + failures + traveltime + absences
# 0.137 	 studytime + goout + Fedu + age + traveltime + failures + Medu
# 0.137 	 studytime + goout + famrel + traveltime + failures + health + absences + Medu
# 0.137 	 studytime + goout + age + traveltime + failures + absences
# 0.137 	 studytime + goout + Fedu + age + traveltime + failures + health + absences + Medu
# 0.137 	 studytime + goout + famrel + failures + absences + traveltime + health + Medu
# 0.137 	 studytime + goout + famrel + Fedu + failures + traveltime + health + absences + Medu
# 0.136 	 studytime + goout + age + failures + traveltime + health + absences + Medu
# 0.136 	 goout + Fedu + traveltime + failures + health + absences + Medu
# 0.136 	 studytime + goout + failures + traveltime + freetime + absences
# 0.136 	 studytime + goout + failures + absences + traveltime + freetime
# 0.136 	 studytime + goout + famrel + age + traveltime + failures + Medu
# 0.136 	 studytime + goout + traveltime + failures + freetime + absences
# 0.136 	 studytime + goout + famrel + Fedu + traveltime + failures + absences
# 0.136 	 goout + Fedu + failures + traveltime + health + absences + Medu
# 0.136 	 studytime + goout + failures + traveltime + absences + freetime
# 0.136 	 studytime + goout + age + traveltime + failures + health + absences + Medu
# 0.136 	 studytime + goout + famrel + Fedu + failures + traveltime + absences
# 0.136 	 studytime + goout + famrel + age + failures + traveltime + Medu
# 0.136 	 goout + failures + absences + Medu
# 0.136 	 studytime + goout + Fedu + age + traveltime + failures + absences
# 0.136 	 studytime + goout + failures + freetime + traveltime + absences
# 0.135 	 studytime + goout + famrel + failures + absences + Medu + freetime
# 0.135 	 studytime + goout + failures + traveltime + Medu + freetime
# 0.135 	 studytime + goout + failures + freetime + traveltime + health + absences + Medu
# 0.135 	 studytime + goout + Fedu + freetime + failures + absences + Medu
# 0.135 	 studytime + goout + Fedu + failures + traveltime + freetime + absences
# 0.135 	 studytime + goout + traveltime + failures + freetime + Medu
# 0.135 	 studytime + goout + age + freetime + failures + absences + Medu
# 0.135 	 studytime + goout + failures + freetime + traveltime + Medu
# 0.135 	 studytime + goout + Fedu + failures + traveltime + health + freetime + absences + Medu
# 0.135 	 studytime + goout + failures + traveltime + freetime + Medu
# 0.135 	 studytime + goout + Fedu + failures + traveltime + absences + freetime
# 0.135 	 studytime + goout + famrel + Fedu + age + traveltime + failures + Medu
# 0.135 	 studytime + goout + famrel + freetime + failures + absences + Medu
# 0.135 	 studytime + goout + Fedu + traveltime + failures + freetime + health + absences + Medu
# 0.135 	 studytime + goout + famrel + failures + freetime + absences + Medu
# 0.135 	 studytime + goout + failures + Medu + traveltime + freetime
# 0.135 	 studytime + goout + famrel + failures + absences + freetime + Medu
# 0.135 	 studytime + goout + Fedu + failures + freetime + absences + Medu
# 0.135 	 studytime + goout + failures + health + absences + Medu
# 0.135 	 goout + failures + absences + traveltime
# 0.135 	 studytime + goout + Fedu + traveltime + failures + freetime + absences
# 0.135 	 goout + failures + traveltime + absences
# 0.135 	 goout + traveltime + failures + absences
# 0.135 	 studytime + goout + traveltime + failures + freetime + health + absences + Medu
# 0.135 	 studytime + goout + age + failures + freetime + absences + Medu
# 0.135 	 studytime + goout + Fedu + failures + absences + freetime + Medu
# 0.135 	 studytime + goout + failures + absences + health + Medu
# 0.135 	 studytime + goout + failures + absences + traveltime + health + freetime + Medu
# 0.135 	 studytime + goout + failures + traveltime + health + freetime + absences + Medu
# 0.134 	 studytime + goout + Fedu + traveltime + failures + freetime + Medu
# 0.134 	 goout + traveltime + failures + health + absences + Medu
# 0.134 	 studytime + goout + famrel + age + failures + traveltime + absences
# 0.134 	 goout + failures + absences + traveltime + health + Medu
# 0.134 	 goout + failures + traveltime + absences + freetime
# 0.134 	 studytime + goout + famrel + Fedu + age + traveltime + failures + health + absences + Medu
# 0.134 	 studytime + goout + Fedu + failures + traveltime + freetime + Medu
# 0.134 	 goout + failures + absences + traveltime + freetime
# 0.134 	 goout + failures + traveltime + freetime + absences
# 0.134 	 goout + Fedu + failures + traveltime + health + freetime + absences + Medu
# 0.134 	 studytime + goout + Fedu + failures + traveltime + Medu + freetime
# 0.134 	 goout + famrel + failures + absences + Medu
# 0.134 	 goout + traveltime + failures + freetime + absences
# 0.134 	 studytime + goout + famrel + age + traveltime + failures + absences
# 0.134 	 goout + failures + freetime + traveltime + absences
# 0.134 	 goout + Fedu + failures + absences + Medu
# 0.134 	 goout + failures + traveltime + health + absences + Medu
# 0.134 	 goout + Fedu + traveltime + failures + freetime + health + absences + Medu
# 0.133 	 goout + failures + traveltime + health + freetime + absences + Medu
# 0.133 	 studytime + goout + famrel + failures + absences + traveltime + freetime
# 0.133 	 studytime + goout + failures + Medu
# 0.133 	 studytime + goout + famrel + failures + traveltime + absences + freetime
# 0.133 	 studytime + goout + famrel + failures + freetime + traveltime + absences
# 0.133 	 studytime + goout + famrel + age + traveltime + failures + health + absences + Medu
# 0.133 	 goout + Fedu + failures + traveltime + absences
# 0.133 	 studytime + goout + age + traveltime + failures + freetime + absences
# 0.133 	 goout + famrel + Fedu + traveltime + failures + health + absences + Medu
# 0.133 	 studytime + goout + age + failures + freetime + traveltime + absences
# 0.133 	 studytime + goout + famrel + age + failures + traveltime + health + absences + Medu
# 0.133 	 studytime + goout + famrel + failures + traveltime + freetime + absences
# 0.133 	 goout + famrel + Fedu + failures + traveltime + health + absences + Medu
# 0.133 	 studytime + goout + famrel + traveltime + failures + freetime + absences
# 0.133 	 goout + failures + freetime + traveltime + health + absences + Medu
# 0.133 	 goout + age + failures + absences + Medu
# 0.133 	 goout + traveltime + failures + freetime + health + absences + Medu
# 0.133 	 goout + Fedu + traveltime + failures + absences
# 0.133 	 goout + failures + absences + traveltime + health + freetime + Medu
# 0.132 	 goout + famrel + failures + absences + traveltime
# 0.132 	 goout + age + failures + traveltime + absences
# 0.132 	 studytime + goout + famrel + Fedu + failures + freetime + absences + Medu
# 0.132 	 studytime + goout + famrel + age + freetime + failures + absences + Medu
# 0.132 	 studytime + goout + Fedu + failures + health + absences + Medu
# 0.132 	 goout + failures + freetime + absences + Medu
# 0.132 	 studytime + goout + famrel + traveltime + failures + freetime + Medu
# 0.132 	 studytime + goout + age + traveltime + failures + freetime + Medu
# 0.132 	 goout + failures + absences + freetime + Medu
# 0.132 	 goout + famrel + traveltime + failures + absences
# 0.132 	 goout + Fedu + failures + traveltime + absences + freetime
# 0.132 	 goout + freetime + failures + absences + Medu
# 0.132 	 studytime + goout + famrel + failures + Medu + traveltime + freetime
# 0.132 	 goout + age + traveltime + failures + absences
# 0.132 	 studytime + goout + famrel + Fedu + freetime + failures + absences + Medu
# 0.132 	 goout + Fedu + failures + traveltime + freetime + absences
# 0.132 	 studytime + goout + famrel + failures + traveltime + freetime + Medu
# 0.132 	 studytime + goout + famrel + failures + absences + health + Medu
# 0.132 	 studytime + goout + famrel + failures + health + absences + Medu
# 0.132 	 studytime + goout + age + failures + freetime + traveltime + Medu
# 0.132 	 studytime + goout + famrel + age + failures + freetime + absences + Medu
# 0.132 	 studytime + goout + famrel + Fedu + failures + absences + freetime + Medu
# 0.132 	 goout + Fedu + age + traveltime + failures + health + absences + Medu
# 0.132 	 goout + Fedu + traveltime + failures + freetime + absences
# 0.132 	 studytime + goout + famrel + failures + traveltime + Medu + freetime
# 0.132 	 studytime + goout + famrel + failures + freetime + traveltime + Medu
# 0.132 	 goout + failures + absences + Medu + freetime
# 0.132 	 studytime + goout + famrel + Fedu + age + traveltime + failures + absences
# 0.132 	 goout + famrel + failures + traveltime + absences
# 0.131 	 goout + Fedu + age + traveltime + failures + freetime + health + absences + Medu
# 0.131 	 goout + famrel + Fedu + failures + absences + Medu
# 0.131 	 goout + failures + traveltime + Medu + freetime
# 0.131 	 goout + traveltime + failures + Medu
# 0.131 	 goout + failures + freetime + traveltime + Medu
# 0.131 	 studytime + goout + age + failures + freetime + traveltime + health + absences + Medu
# 0.131 	 studytime + goout + famrel + failures + Medu
# 0.131 	 goout + famrel + traveltime + failures + freetime + absences
# 0.131 	 studytime + goout + famrel + traveltime + failures + freetime + health + absences + Medu
# 0.131 	 goout + famrel + failures + freetime + traveltime + absences
# 0.131 	 goout + traveltime + failures + freetime + Medu
# 0.131 	 studytime + goout + age + traveltime + failures + freetime + health + absences + Medu
# 0.131 	 goout + failures + Medu + traveltime + freetime
# 0.131 	 studytime + goout + Fedu + age + freetime + failures + absences + Medu
# 0.131 	 goout + failures + Medu + traveltime
# 0.131 	 studytime + goout + Fedu + age + traveltime + failures + freetime + health + absences + Medu
# 0.131 	 goout + famrel + failures + traveltime + absences + freetime
# 0.131 	 studytime + goout + famrel + Fedu + traveltime + failures + freetime + absences
# 0.131 	 studytime + goout + Fedu + age + traveltime + failures + freetime + absences
# 0.131 	 studytime + goout + famrel + failures + traveltime + health + freetime + absences + Medu
# 0.131 	 studytime + goout + Fedu + age + failures + freetime + absences + Medu
# 0.131 	 studytime + goout + famrel + failures + absences + traveltime + health + freetime + Medu
# 0.131 	 studytime + goout + Fedu + failures + absences
# 0.131 	 goout + failures + traveltime + Medu
# 0.131 	 goout + famrel + failures + absences + traveltime + freetime
# 0.131 	 studytime + goout + famrel + Fedu + failures + traveltime + absences + freetime
# 0.131 	 studytime + goout + famrel + Fedu + failures + traveltime + freetime + absences
# 0.131 	 goout + age + failures + freetime + traveltime + absences
# 0.131 	 goout + famrel + Fedu + failures + traveltime + health + freetime + absences + Medu
# 0.131 	 goout + age + traveltime + failures + freetime + absences
# 0.131 	 goout + failures + traveltime + freetime + Medu
# 0.131 	 studytime + goout + famrel + Fedu + traveltime + failures + freetime + health + absences + Medu
# 0.131 	 goout + famrel + age + failures + absences + Medu
# 0.131 	 studytime + goout + famrel + failures + freetime + traveltime + health + absences + Medu
# 0.131 	 studytime + goout + age + failures + health + absences + Medu
# 0.131 	 goout + famrel + failures + traveltime + freetime + absences
# 0.131 	 studytime + goout + famrel + Fedu + failures + traveltime + health + freetime + absences + Medu
# 0.131 	 goout + famrel + Fedu + traveltime + failures + freetime + health + absences + Medu
# 0.13 	 goout + Fedu + age + failures + absences + Medu
# 0.13 	 studytime + goout + famrel + Fedu + failures + health + absences + Medu
# 0.13 	 goout + famrel + failures + traveltime + health + absences + Medu
# 0.13 	 goout + famrel + Fedu + failures + traveltime + absences
# 0.13 	 goout + age + traveltime + failures + health + absences + Medu
# 0.13 	 goout + famrel + Fedu + traveltime + failures + absences
# 0.13 	 studytime + goout + famrel + Fedu + failures + traveltime + freetime + Medu
# 0.13 	 studytime + goout + Fedu + age + traveltime + failures + freetime + Medu
# 0.13 	 studytime + goout + famrel + Fedu + traveltime + failures + freetime + Medu
# 0.13 	 goout + Fedu + failures + traveltime + Medu
# 0.13 	 goout + Fedu + age + traveltime + failures + absences
# 0.13 	 goout + famrel + traveltime + failures + health + absences + Medu
# 0.13 	 goout + Fedu + traveltime + failures + Medu
# 0.13 	 goout + famrel + failures + absences + traveltime + health + Medu
# 0.13 	 studytime + goout + Fedu + failures + Medu
# 0.13 	 goout + age + failures + traveltime + health + absences + Medu
# 0.13 	 studytime + goout + famrel + Fedu + failures + traveltime + Medu + freetime
# 0.13 	 studytime + goout + age + failures + Medu
# 0.129 	 goout + famrel + Fedu + failures + traveltime + freetime + absences
# 0.129 	 goout + famrel + freetime + failures + absences + Medu
# 0.129 	 goout + Fedu + traveltime + failures + freetime + Medu
# 0.129 	 goout + famrel + failures + absences + traveltime + health + freetime + Medu
# 0.129 	 goout + Fedu + freetime + failures + absences + Medu
# 0.129 	 goout + famrel + failures + freetime + absences + Medu
# 0.129 	 goout + age + traveltime + failures + freetime + health + absences + Medu
# 0.129 	 goout + Fedu + age + traveltime + failures + freetime + absences
# 0.129 	 goout + famrel + traveltime + failures + freetime + health + absences + Medu
# 0.129 	 goout + famrel + Fedu + traveltime + failures + freetime + absences
# 0.129 	 studytime + goout + traveltime + failures + health + absences
# 0.129 	 goout + Fedu + failures + traveltime + freetime + Medu
# 0.129 	 goout + famrel + failures + absences + freetime + Medu
# 0.129 	 goout + age + failures + freetime + traveltime + health + absences + Medu
# 0.129 	 goout + famrel + age + failures + traveltime + absences
# 0.129 	 studytime + goout + famrel + age + traveltime + failures + freetime + absences
# 0.129 	 goout + Fedu + failures + absences + freetime + Medu
# 0.129 	 goout + famrel + failures + freetime + traveltime + health + absences + Medu
# 0.129 	 goout + Fedu + failures + traveltime + Medu + freetime
# 0.129 	 goout + Fedu + failures + freetime + absences + Medu
# 0.129 	 goout + famrel + Fedu + age + traveltime + failures + health + absences + Medu
# 0.129 	 studytime + goout + famrel + age + failures + freetime + traveltime + absences
# 0.129 	 goout + famrel + failures + traveltime + health + freetime + absences + Medu
# 0.129 	 studytime + goout + failures + traveltime + health + absences
# 0.129 	 goout + famrel + Fedu + failures + traveltime + absences + freetime
# 0.129 	 studytime + goout + famrel + age + failures + Medu
# 0.129 	 goout + famrel + failures + absences + Medu + freetime
# 0.129 	 studytime + goout + failures + absences + traveltime + health
# 0.129 	 studytime + goout + famrel + age + failures + health + absences + Medu
# 0.129 	 studytime + goout + Fedu + age + failures + health + absences + Medu
# 0.129 	 goout + famrel + age + traveltime + failures + absences
# 0.128 	 studytime + goout + failures + absences
# 0.128 	 goout + famrel + failures + traveltime + Medu
# 0.128 	 studytime + goout + famrel + age + traveltime + failures + freetime + Medu
# 0.128 	 goout + famrel + failures + Medu + traveltime
# 0.128 	 studytime + goout + famrel + Fedu + age + failures + freetime + absences + Medu
# 0.128 	 studytime + goout + famrel + Fedu + age + freetime + failures + absences + Medu
# 0.128 	 goout + age + freetime + failures + absences + Medu
# 0.128 	 goout + age + failures + freetime + absences + Medu
# 0.128 	 studytime + goout + famrel + Fedu + failures + absences
# 0.128 	 goout + famrel + traveltime + failures + Medu
# 0.128 	 studytime + goout + famrel + age + failures + freetime + traveltime + Medu
# 0.128 	 goout + age + failures + traveltime + Medu
# 0.128 	 studytime + goout + famrel + Fedu + age + traveltime + failures + freetime + absences
# 0.128 	 goout + age + traveltime + failures + Medu
# 0.128 	 goout + famrel + Fedu + age + failures + absences + Medu
# 0.128 	 studytime + goout + famrel + Fedu + failures + Medu
# 0.128 	 studytime + goout + Fedu + age + failures + absences
# 0.127 	 studytime + goout + famrel + age + traveltime + failures + freetime + health + absences + Medu
# 0.127 	 studytime + goout + famrel + Fedu + age + traveltime + failures + freetime + Medu
# 0.127 	 goout + famrel + Fedu + traveltime + failures + Medu
# 0.127 	 goout + Fedu + age + traveltime + failures + Medu
# 0.127 	 studytime + goout + famrel + age + failures + freetime + traveltime + health + absences + Medu
# 0.127 	 goout + famrel + failures + freetime + traveltime + Medu
# 0.127 	 goout + famrel + failures + Medu + traveltime + freetime
# 0.127 	 goout + famrel + failures + traveltime + freetime + Medu
# 0.127 	 studytime + goout + Fedu + age + failures + Medu
# 0.127 	 goout + famrel + Fedu + age + traveltime + failures + freetime + health + absences + Medu
# 0.127 	 goout + famrel + failures + traveltime + Medu + freetime
# 0.127 	 goout + famrel + Fedu + age + traveltime + failures + absences
# 0.127 	 goout + age + failures + freetime + traveltime + Medu
# 0.127 	 goout + famrel + Fedu + failures + traveltime + Medu
# 0.127 	 studytime + goout + famrel + Fedu + age + traveltime + failures + freetime + health + absences + Medu
# 0.127 	 goout + famrel + age + traveltime + failures + health + absences + Medu
# 0.127 	 goout + famrel + age + failures + traveltime + health + absences + Medu
# 0.127 	 goout + age + traveltime + failures + freetime + Medu
# 0.127 	 goout + famrel + age + failures + freetime + traveltime + absences
# 0.127 	 goout + famrel + age + traveltime + failures + freetime + absences
# 0.127 	 goout + famrel + traveltime + failures + freetime + Medu
# 0.126 	 goout + famrel + age + failures + freetime + traveltime + health + absences + Medu
# 0.126 	 studytime + goout + famrel + Fedu + age + failures + health + absences + Medu
# 0.126 	 studytime + goout + age + traveltime + failures + health + absences
# 0.126 	 goout + Fedu + age + failures + freetime + absences + Medu
# 0.126 	 studytime + goout + famrel + traveltime + failures + health + absences
# 0.126 	 goout + Fedu + age + traveltime + failures + freetime + Medu
# 0.126 	 goout + famrel + Fedu + failures + traveltime + freetime + Medu
# 0.126 	 studytime + goout + Fedu + failures + traveltime + health + Medu
# 0.126 	 studytime + goout + famrel + failures + absences
# 0.126 	 goout + Fedu + age + freetime + failures + absences + Medu
# 0.126 	 studytime + goout + famrel + Fedu + age + failures + Medu
# 0.126 	 studytime + goout + Fedu + failures + traveltime + health + absences
# 0.126 	 goout + famrel + Fedu + failures + traveltime + Medu + freetime
# 0.126 	 studytime + goout + famrel + failures + absences + traveltime + health
# 0.126 	 studytime + goout + failures + traveltime
# 0.126 	 studytime + goout + Fedu + traveltime + failures + health + absences
# 0.126 	 goout + famrel + Fedu + traveltime + failures + freetime + Medu
# 0.126 	 studytime + goout + age + failures + traveltime + health + absences
# 0.126 	 studytime + goout + Fedu + traveltime + failures + health + Medu
# 0.126 	 goout + famrel + age + traveltime + failures + freetime + health + absences + Medu
# 0.126 	 goout + famrel + Fedu + freetime + failures + absences + Medu
# 0.126 	 studytime + goout + famrel + failures + traveltime + health + absences
# 0.126 	 studytime + goout + traveltime + failures
# 0.126 	 goout + famrel + Fedu + failures + absences + freetime + Medu
# 0.126 	 goout + famrel + Fedu + failures + freetime + absences + Medu
# 0.125 	 studytime + goout + famrel + Fedu + age + failures + absences
# 0.125 	 studytime + goout + Fedu + failures + traveltime
# 0.125 	 goout + famrel + age + failures + traveltime + Medu
# 0.125 	 goout + famrel + age + freetime + failures + absences + Medu
# 0.125 	 studytime + goout + Fedu + traveltime + failures
# 0.125 	 studytime + goout + failures + Medu + traveltime + health
# 0.125 	 studytime + goout + failures + traveltime + health + Medu
# 0.125 	 studytime + goout + age + failures + absences
# 0.125 	 goout + famrel + Fedu + age + traveltime + failures + freetime + absences
# 0.125 	 goout + famrel + age + traveltime + failures + Medu
# 0.125 	 studytime + goout + traveltime + failures + health + Medu
# 0.125 	 goout + famrel + age + failures + freetime + absences + Medu
# 0.124 	 studytime + goout + failures + absences + health + freetime + Medu
# 0.124 	 goout + famrel + age + failures + freetime + traveltime + Medu
# 0.124 	 studytime + goout + failures + absences + freetime + health + Medu
# 0.124 	 studytime + goout + freetime + failures + health + absences + Medu
# 0.124 	 studytime + goout + failures + health + freetime + absences + Medu
# 0.124 	 studytime + goout + failures + freetime + health + absences + Medu
# 0.124 	 studytime + goout + failures + freetime + traveltime + health + absences
# 0.124 	 studytime + goout + failures + traveltime + health + freetime + absences
# 0.124 	 studytime + goout + traveltime + failures + freetime + health + absences
# 0.124 	 studytime + goout + failures + absences + traveltime + health + freetime
# 0.124 	 studytime + goout + age + failures + traveltime
# 0.124 	 goout + famrel + age + traveltime + failures + freetime + Medu
# 0.124 	 goout + famrel + Fedu + age + traveltime + failures + Medu
# 0.124 	 studytime + goout + age + traveltime + failures
# 0.123 	 studytime + goout + failures + freetime + Medu
# 0.123 	 goout + failures + absences + traveltime + health
# 0.123 	 studytime + goout + failures + Medu + freetime
# 0.123 	 goout + traveltime + failures + health + absences
# 0.123 	 goout + famrel + Fedu + age + freetime + failures + absences + Medu
# 0.123 	 studytime + goout + famrel + Fedu + traveltime + failures + health + Medu
# 0.123 	 goout + famrel + Fedu + age + failures + freetime + absences + Medu
# 0.123 	 studytime + goout + famrel + age + failures + absences
# 0.123 	 studytime + goout + freetime + failures + Medu
# 0.123 	 studytime + goout + famrel + Fedu + failures + traveltime + health + Medu
# 0.123 	 studytime + goout + famrel + traveltime + failures
# 0.123 	 studytime + goout + famrel + failures + traveltime
# 0.123 	 goout + failures + traveltime + health + absences
# 0.123 	 studytime + goout + Fedu + age + traveltime + failures + health + Medu
# 0.122 	 studytime + goout + age + failures + traveltime + health + Medu
# 0.122 	 studytime + goout + age + traveltime + failures + health + Medu
# 0.122 	 studytime + goout + Fedu + freetime + failures + absences
# 0.122 	 goout + failures + absences + health + Medu
# 0.122 	 studytime + goout + famrel + Fedu + failures + traveltime + health + absences
# 0.122 	 studytime + goout + famrel + failures + Medu + traveltime + health
# 0.122 	 studytime + goout + Fedu + failures + freetime + absences
# 0.122 	 studytime + goout + famrel + Fedu + traveltime + failures + health + absences
# 0.122 	 studytime + goout + famrel + age + traveltime + failures + health + absences
# 0.122 	 studytime + goout + famrel + age + failures + traveltime + health + absences
# 0.122 	 goout + failures + traveltime + health + freetime + absences
# 0.122 	 goout + failures + health + absences + Medu
# 0.122 	 studytime + goout + famrel + traveltime + failures + health + Medu
# 0.122 	 goout + traveltime + failures + freetime + health + absences
# 0.122 	 studytime + goout + Fedu + age + traveltime + failures + health + absences
# 0.122 	 goout + failures + absences + traveltime + health + freetime
# 0.122 	 goout + failures + freetime + traveltime + health + absences
# 0.122 	 studytime + goout + famrel + Fedu + traveltime + failures
# 0.122 	 studytime + goout + famrel + failures + traveltime + health + Medu
# 0.122 	 studytime + goout + Fedu + age + traveltime + failures
# 0.122 	 goout + famrel + Fedu + age + traveltime + failures + freetime + Medu
# 0.122 	 studytime + goout + famrel + Fedu + failures + traveltime
# 0.122 	 studytime + goout + Fedu + failures + absences + freetime
# 0.121 	 studytime + goout + failures + health + absences
# 0.121 	 studytime + goout + famrel + failures + traveltime + health + freetime + absences
# 0.121 	 studytime + goout + famrel + failures + absences + freetime + health + Medu
# 0.121 	 studytime + goout + famrel + failures + absences + traveltime + health + freetime
# 0.121 	 studytime + goout + failures + freetime + traveltime
# 0.121 	 studytime + goout + famrel + freetime + failures + health + absences + Medu
# 0.121 	 studytime + goout + famrel + failures + absences + health + freetime + Medu
# 0.121 	 studytime + goout + failures + traveltime + freetime
# 0.121 	 studytime + goout + famrel + failures + health + freetime + absences + Medu
# 0.121 	 studytime + goout + age + failures + freetime + health + absences + Medu
# 0.121 	 studytime + goout + famrel + traveltime + failures + freetime + health + absences
# 0.121 	 studytime + goout + failures + absences + health
# 0.121 	 studytime + goout + traveltime + failures + freetime
# 0.121 	 studytime + goout + famrel + failures + freetime + traveltime + health + absences
# 0.121 	 studytime + goout + Fedu + freetime + failures + health + absences + Medu
# 0.121 	 studytime + goout + Fedu + failures + freetime + health + absences + Medu
# 0.121 	 studytime + goout + age + failures + freetime + traveltime + health + absences
# 0.121 	 studytime + goout + Fedu + failures + traveltime + health + freetime + absences
# 0.121 	 studytime + goout + Fedu + failures + health + freetime + absences + Medu
# 0.121 	 studytime + goout + Fedu + traveltime + failures + freetime + health + absences
# 0.121 	 studytime + goout + age + traveltime + failures + freetime + health + absences
# 0.121 	 studytime + goout + famrel + failures + freetime + health + absences + Medu
# 0.121 	 studytime + goout + age + freetime + failures + health + absences + Medu
# 0.12 	 studytime + goout + famrel + age + failures + traveltime
# 0.12 	 studytime + goout + Fedu + freetime + failures + Medu
# 0.12 	 studytime + goout + famrel + age + traveltime + failures
# 0.12 	 studytime + goout + famrel + failures + freetime + Medu
# 0.12 	 goout + famrel + failures + traveltime + health + absences
# 0.12 	 goout + Fedu + traveltime + failures + health + absences
# 0.12 	 goout + Fedu + failures + health + absences + Medu
# 0.12 	 goout + Fedu + failures + traveltime + health + absences
# 0.12 	 studytime + goout + age + freetime + failures + Medu
# 0.12 	 goout + famrel + traveltime + failures + health + absences
# 0.12 	 studytime + goout + famrel + freetime + failures + Medu
# 0.12 	 studytime + goout + Fedu + failures + freetime + Medu
# 0.12 	 studytime + goout + Fedu + failures + health + absences
# 0.12 	 studytime + goout + Fedu + failures + Medu + freetime
# 0.12 	 goout + age + failures + traveltime + health + absences
# 0.12 	 studytime + goout + famrel + Fedu + age + traveltime + failures + health + Medu
# 0.12 	 goout + age + traveltime + failures + health + absences
# 0.12 	 studytime + goout + famrel + failures + Medu + freetime
# 0.12 	 studytime + goout + age + failures + freetime + Medu
# 0.12 	 goout + famrel + failures + absences + traveltime + health
# 0.119 	 studytime + goout + traveltime + failures + freetime + health + Medu
# 0.119 	 studytime + goout + Fedu + traveltime + failures + freetime
# 0.119 	 goout + age + traveltime + failures + freetime + health + absences
# 0.119 	 studytime + goout + famrel + Fedu + age + traveltime + failures + health + absences
# 0.119 	 studytime + goout + failures + absences + freetime
# 0.119 	 studytime + goout + failures + Medu + health
# 0.119 	 studytime + goout + famrel + Fedu + age + traveltime + failures
# 0.119 	 studytime + goout + failures + Medu + traveltime + health + freetime
# 0.119 	 studytime + goout + failures + freetime + absences
# 0.119 	 studytime + goout + failures + freetime + traveltime + health + Medu
# 0.119 	 studytime + goout + Fedu + traveltime + failures + freetime + health + Medu
# 0.119 	 studytime + goout + freetime + failures + absences
# 0.119 	 goout + age + failures + freetime + traveltime + health + absences
# 0.119 	 studytime + goout + Fedu + age + failures + freetime + absences
# 0.119 	 studytime + goout + Fedu + age + freetime + failures + absences
# 0.119 	 studytime + goout + Fedu + failures + traveltime + health + freetime + Medu
# 0.119 	 studytime + goout + famrel + age + traveltime + failures + health + Medu
# 0.119 	 studytime + goout + famrel + age + failures + traveltime + health + Medu
# 0.119 	 studytime + goout + failures + traveltime + health + freetime + Medu
# 0.119 	 studytime + goout + failures + health + Medu
# 0.119 	 studytime + goout + Fedu + failures + traveltime + freetime
# 0.119 	 goout + famrel + failures + health + absences + Medu
# 0.119 	 goout + famrel + failures + absences + health + Medu
# 0.118 	 studytime + goout + famrel + age + failures + freetime + Medu
# 0.118 	 studytime + goout + famrel + age + freetime + failures + Medu
# 0.118 	 goout + famrel + Fedu + failures + health + absences + Medu
# 0.118 	 studytime + goout + famrel + Fedu + freetime + failures + health + absences + Medu
# 0.118 	 goout + famrel + failures + absences + traveltime + health + freetime
# 0.118 	 goout + age + failures + health + absences + Medu
# 0.118 	 studytime + goout + famrel + failures + freetime + traveltime
# 0.118 	 studytime + goout + famrel + failures + health + Medu
# 0.118 	 studytime + goout + famrel + age + failures + freetime + health + absences + Medu
# 0.118 	 studytime + goout + famrel + Fedu + failures + freetime + health + absences + Medu
# 0.118 	 studytime + goout + famrel + failures + absences + health
# 0.118 	 studytime + goout + Fedu + age + freetime + failures + health + absences + Medu
# 0.118 	 studytime + goout + famrel + failures + health + absences
# 0.118 	 goout + famrel + failures + traveltime + health + freetime + absences
# 0.118 	 goout + failures + Medu
# 0.118 	 studytime + goout + famrel + age + freetime + failures + health + absences + Medu
# 0.118 	 goout + famrel + failures + freetime + traveltime + health + absences
# 0.118 	 studytime + goout + famrel + failures + Medu + health
# 0.118 	 goout + Fedu + traveltime + failures + freetime + health + absences
# 0.118 	 studytime + goout + famrel + Fedu + failures + absences + freetime
# 0.118 	 studytime + goout + age + traveltime + failures + freetime
# 0.118 	 studytime + goout + age + failures + freetime + traveltime
# 0.118 	 goout + Fedu + failures + traveltime + health + freetime + absences
# 0.118 	 studytime + goout + Fedu + age + failures + freetime + health + absences + Medu
# 0.118 	 goout + famrel + traveltime + failures + freetime + health + absences
# 0.118 	 studytime + goout + famrel + Fedu + freetime + failures + absences
# 0.118 	 studytime + goout + famrel + Fedu + failures + freetime + absences
# 0.118 	 goout + Fedu + failures + absences
# 0.118 	 studytime + goout + famrel + failures + traveltime + freetime
# 0.118 	 studytime + goout + famrel + traveltime + failures + freetime
# 0.118 	 studytime + goout + famrel + Fedu + failures + health + freetime + absences + Medu
# 0.118 	 studytime + goout + age + failures + health + absences
# 0.117 	 goout + failures + absences + freetime + health + Medu
# 0.117 	 studytime + goout + Fedu + age + traveltime + failures + freetime + health + absences
# 0.117 	 studytime + goout + famrel + age + traveltime + failures + freetime + health + absences
# 0.117 	 goout + Fedu + age + failures + health + absences + Medu
# 0.117 	 goout + failures + health + freetime + absences + Medu
# 0.117 	 goout + freetime + failures + health + absences + Medu
# 0.117 	 studytime + goout + famrel + Fedu + failures + Medu + freetime
# 0.117 	 goout + failures + absences + health + freetime + Medu
# 0.117 	 studytime + goout + Fedu + age + freetime + failures + Medu
# 0.117 	 goout + failures + freetime + health + absences + Medu
# 0.117 	 studytime + goout + Fedu + age + failures + health + absences
# 0.117 	 studytime + goout + famrel + Fedu + traveltime + failures + freetime + health + absences
# 0.117 	 studytime + goout + Fedu + age + failures + freetime + Medu
# 0.117 	 studytime + goout + famrel + Fedu + failures + freetime + Medu
# 0.117 	 studytime + goout + age + failures + health + Medu
# 0.117 	 studytime + goout + Fedu + failures
# 0.117 	 studytime + goout + famrel + Fedu + failures + health + absences
# 0.117 	 studytime + goout + famrel + Fedu + failures + traveltime + health + freetime + absences
# 0.117 	 studytime + goout + famrel + Fedu + freetime + failures + Medu
# 0.117 	 studytime + goout + famrel + age + failures + freetime + traveltime + health + absences
# 0.117 	 studytime + goout + Fedu + failures + health + Medu
# 0.116 	 goout + famrel + age + failures + health + absences + Medu
# 0.116 	 studytime + goout + famrel + Fedu + failures + traveltime + freetime
# 0.116 	 studytime + goout + famrel + Fedu + traveltime + failures + freetime
# 0.116 	 studytime + goout + age + freetime + failures + absences
# 0.116 	 goout + failures + absences
# 0.116 	 goout + famrel + failures + Medu
# 0.116 	 goout + famrel + Fedu + traveltime + failures + health + absences
# 0.116 	 studytime + goout + famrel + failures + freetime + absences
# 0.116 	 goout + famrel + age + failures + traveltime + health + absences
# 0.116 	 studytime + goout + famrel + freetime + failures + absences
# 0.116 	 studytime + goout + Fedu + age + traveltime + failures + freetime
# 0.116 	 studytime + goout + famrel + failures + absences + freetime
# 0.116 	 studytime + failures + absences + Medu
# 0.116 	 studytime + goout + failures
# 0.116 	 goout + Fedu + age + traveltime + failures + health + absences
# 0.116 	 goout + famrel + Fedu + failures + traveltime + health + absences
# 0.116 	 goout + famrel + age + traveltime + failures + health + absences
# 0.116 	 studytime + goout + age + failures + freetime + absences
# 0.115 	 goout + Fedu + failures + traveltime + health + Medu
# 0.115 	 goout + famrel + age + traveltime + failures + freetime + health + absences
# 0.115 	 studytime + goout + famrel + Fedu + failures + traveltime + health + freetime + Medu
# 0.115 	 studytime + goout + famrel + age + traveltime + failures + freetime
# 0.115 	 goout + Fedu + failures + freetime + health + absences + Medu
# 0.115 	 goout + Fedu + failures + health + freetime + absences + Medu
# 0.115 	 studytime + goout + famrel + Fedu + age + failures + freetime + absences
# 0.115 	 goout + Fedu + failures + Medu
# 0.115 	 studytime + goout + famrel + Fedu + traveltime + failures + freetime + health + Medu
# 0.115 	 studytime + goout + famrel + age + failures + health + Medu
# 0.115 	 goout + famrel + Fedu + traveltime + failures + freetime + health + absences
# 0.115 	 goout + age + failures + Medu
# 0.115 	 studytime + goout + famrel + Fedu + age + freetime + failures + absences
# 0.115 	 studytime + goout + famrel + Fedu + failures
# 0.115 	 studytime + goout + famrel + Fedu + age + failures + freetime + Medu
# 0.115 	 goout + famrel + Fedu + failures + traveltime + health + freetime + absences
# 0.115 	 studytime + goout + age + failures + freetime + traveltime + health + Medu
# 0.115 	 goout + Fedu + freetime + failures + health + absences + Medu
# 0.115 	 studytime + goout + famrel + failures + freetime + traveltime + health + Medu
# 0.115 	 studytime + goout + famrel + Fedu + age + freetime + failures + Medu
# 0.115 	 goout + famrel + age + failures + freetime + traveltime + health + absences
# 0.115 	 studytime + goout + Fedu + age + failures
# 0.115 	 studytime + goout + famrel + traveltime + failures + freetime + health + Medu
# 0.115 	 studytime + goout + famrel + failures + Medu + traveltime + health + freetime
# 0.115 	 studytime + goout + famrel + Fedu + age + freetime + failures + health + absences + Medu
# 0.115 	 goout + famrel + Fedu + failures + absences
# 0.115 	 studytime + goout + traveltime + failures + health
# 0.115 	 goout + Fedu + age + traveltime + failures + freetime + health + absences
# 0.115 	 studytime + goout + Fedu + age + traveltime + failures + freetime + health + Medu
# 0.115 	 studytime + goout + famrel + Fedu + failures + health + Medu
# 0.115 	 studytime + goout + famrel + Fedu + age + failures + freetime + health + absences + Medu
# 0.115 	 studytime + goout + age + traveltime + failures + freetime + health + Medu
# 0.115 	 studytime + goout + famrel + age + failures + health + absences
# 0.115 	 studytime + goout + famrel + age + failures + freetime + traveltime
# 0.115 	 studytime + goout + famrel + failures + traveltime + health + freetime + Medu
# 0.115 	 goout + Fedu + traveltime + failures + health + Medu
# 0.115 	 studytime + goout + failures + traveltime + health
# 0.114 	 goout + traveltime + failures + health + Medu
# 0.114 	 goout + failures + Medu + traveltime + health + freetime
# 0.114 	 goout + traveltime + failures
# 0.114 	 goout + failures + Medu + traveltime + health
# 0.114 	 goout + freetime + failures + Medu
# 0.114 	 goout + failures + traveltime
# 0.114 	 studytime + goout + famrel + failures
# 0.114 	 goout + failures + traveltime + health + freetime + Medu
# 0.114 	 studytime + goout + famrel + Fedu + age + traveltime + failures + freetime + health + absences
# 0.114 	 goout + Fedu + age + failures + absences
# 0.114 	 goout + famrel + failures + absences + freetime + health + Medu
# 0.114 	 goout + failures + freetime + Medu
# 0.114 	 studytime + goout + Fedu + age + failures + health + Medu
# 0.114 	 goout + failures + freetime + traveltime + health + Medu
# 0.114 	 goout + famrel + failures + absences + health + freetime + Medu
# 0.114 	 goout + traveltime + failures + freetime + health + Medu
# 0.114 	 studytime + goout + famrel + Fedu + age + failures + health + absences
# 0.114 	 goout + failures + traveltime + health + Medu
# 0.114 	 goout + failures + Medu + freetime
# 0.114 	 goout + famrel + failures + absences
# 0.114 	 goout + traveltime + failures + freetime
# 0.114 	 goout + Fedu + traveltime + failures + freetime + health + Medu
# 0.114 	 goout + age + freetime + failures + health + absences + Medu
# 0.114 	 goout + Fedu + failures + traveltime + health + freetime + Medu
# 0.114 	 goout + famrel + failures + freetime + health + absences + Medu
# 0.114 	 goout + failures + freetime + traveltime
# 0.114 	 goout + famrel + freetime + failures + health + absences + Medu
# 0.114 	 goout + age + failures + freetime + health + absences + Medu
# 0.114 	 goout + famrel + Fedu + age + failures + health + absences + Medu
# 0.114 	 goout + failures + traveltime + freetime
# 0.114 	 goout + famrel + failures + health + freetime + absences + Medu
# 0.113 	 goout + Fedu + age + failures + Medu
# 0.113 	 goout + Fedu + failures + freetime + absences
# 0.113 	 goout + Fedu + traveltime + failures + freetime
# 0.113 	 studytime + goout + famrel + Fedu + age + traveltime + failures + freetime
# 0.113 	 goout + famrel + Fedu + failures + Medu
# 0.113 	 studytime + age + failures + absences + Medu
# 0.113 	 goout + famrel + Fedu + age + traveltime + failures + health + absences
# 0.113 	 studytime + goout + famrel + Fedu + age + failures + health + Medu
# 0.113 	 studytime + goout + age + failures + traveltime + health
# 0.113 	 studytime + goout + famrel + age + freetime + failures + absences
# 0.113 	 studytime + goout + age + failures
# 0.113 	 studytime + goout + famrel + age + failures + freetime + absences
# 0.113 	 studytime + goout + famrel + Fedu + age + failures
# 0.113 	 studytime + famrel + failures + absences + Medu
# 0.113 	 goout + famrel + age + failures + Medu
# 0.113 	 goout + Fedu + freetime + failures + absences
# 0.113 	 goout + Fedu + failures + traveltime
# 0.113 	 studytime + goout + age + traveltime + failures + health
# 0.113 	 goout + age + failures + absences
# ...
# 0.0223 	 studytime + famrel + Medu + traveltime + health
# 0.0223 	 studytime + famrel + traveltime + health + Medu
# 0.0222 	 famrel + Medu + freetime
# 0.0222 	 goout + famrel + traveltime + health
# 0.0222 	 goout + famrel + health + traveltime
# 0.0222 	 famrel + freetime + Medu
# 0.0221 	 studytime + Fedu + age + traveltime + freetime
# 0.022 	 studytime + Fedu + Medu + traveltime + health
# 0.022 	 studytime + age + health + traveltime
# 0.022 	 studytime + age + traveltime + health
# 0.022 	 studytime + Fedu + traveltime + health + Medu
# 0.022 	 famrel + Fedu + traveltime + Medu
# 0.022 	 famrel + Fedu + Medu + traveltime
# 0.0218 	 absences + traveltime + health + freetime
# 0.0218 	 freetime + traveltime + absences
# 0.0218 	 absences + freetime + traveltime
# 0.0218 	 health + Medu
# 0.0218 	 traveltime + freetime + health + absences
# 0.0218 	 traveltime + health + freetime + absences
# 0.0218 	 absences + freetime + health + traveltime
# 0.0218 	 traveltime + absences + freetime
# 0.0218 	 absences + traveltime + freetime
# 0.0218 	 freetime + traveltime + health + absences
# 0.0218 	 traveltime + freetime + absences
# 0.0218 	 Medu + health
# 0.0217 	 Fedu + age + health
# 0.0213 	 studytime + famrel + freetime + traveltime + Medu
# 0.0213 	 studytime + famrel + traveltime + freetime + Medu
# 0.0213 	 studytime + famrel + traveltime + Medu + freetime
# 0.0213 	 studytime + famrel + Medu + freetime + traveltime
# 0.0213 	 studytime + famrel + Medu + traveltime + freetime
# 0.0213 	 studytime + famrel + freetime + Medu + traveltime
# 0.0212 	 studytime + Fedu + traveltime + Medu + freetime
# 0.0212 	 studytime + Fedu + traveltime + freetime + Medu
# 0.0212 	 studytime + Fedu + Medu + traveltime + freetime
# 0.0208 	 famrel + Fedu + traveltime + freetime + health + absences
# 0.0208 	 famrel + Fedu + absences + traveltime + health + freetime
# 0.0208 	 famrel + Fedu + traveltime + health + freetime + absences
# 0.0207 	 famrel + Fedu + age + health
# 0.0207 	 studytime + famrel + age + traveltime
# 0.0206 	 Fedu + age + traveltime
# 0.0204 	 Fedu + age + health + freetime
# 0.0204 	 studytime + famrel + Fedu + age + traveltime + health
# 0.0204 	 studytime + famrel + Fedu + Medu + freetime + health
# 0.0204 	 studytime + famrel + Fedu + Medu + health + freetime
# 0.0204 	 studytime + famrel + Fedu + health + freetime + Medu
# 0.0204 	 studytime + famrel + Fedu + freetime + health + Medu
# 0.0204 	 Fedu + age + freetime + health
# 0.0203 	 famrel + Fedu + age + traveltime + health + freetime + Medu
# 0.0203 	 famrel + Fedu + age + traveltime + freetime + health + Medu
# 0.0202 	 studytime + Fedu + traveltime
# 0.0201 	 Fedu + Medu + traveltime + freetime
# 0.0201 	 famrel + Medu + traveltime + freetime
# 0.0201 	 famrel + freetime + Medu + traveltime
# 0.0201 	 Fedu + traveltime + freetime + Medu
# 0.0201 	 Fedu + traveltime + Medu + freetime
# 0.0201 	 famrel + freetime + traveltime + Medu
# 0.0201 	 famrel + traveltime + freetime + Medu
# 0.0201 	 famrel + traveltime + Medu + freetime
# 0.0201 	 famrel + Medu + freetime + traveltime
# 0.02 	 Fedu + age + traveltime + freetime
# 0.0199 	 studytime + famrel + Fedu + age + traveltime + freetime + health + Medu
# 0.0199 	 studytime + famrel + Fedu + age + traveltime + health + freetime + Medu
# 0.0198 	 studytime + famrel + age + health + traveltime
# 0.0198 	 studytime + famrel + age + traveltime + health
# 0.0197 	 famrel + freetime + absences
# 0.0197 	 famrel + absences + freetime
# 0.0197 	 goout + famrel
# 0.0196 	 famrel + Fedu + freetime + Medu
# 0.0196 	 famrel + Fedu + Medu + freetime
# 0.0195 	 famrel + Medu + health
# 0.0195 	 famrel + health + Medu
# 0.0194 	 goout + Fedu + freetime + health
# 0.0194 	 goout + Fedu + health + freetime
# 0.0191 	 studytime + famrel + Fedu + age + traveltime + freetime
# 0.0191 	 studytime + health
# 0.019 	 famrel + Fedu + age + freetime + health
# 0.019 	 famrel + Fedu + age + health + freetime
# 0.019 	 studytime
# 0.0189 	 goout + famrel + Fedu + traveltime + health + freetime
# 0.0189 	 goout + famrel + Fedu + freetime + traveltime + health
# 0.0189 	 goout + famrel + Fedu + traveltime + freetime + health
# 0.0188 	 studytime + famrel + Fedu + Medu + traveltime + health
# 0.0188 	 studytime + famrel + Fedu + traveltime + health + Medu
# 0.0187 	 Medu + health + traveltime
# 0.0187 	 traveltime + health + Medu
# 0.0187 	 Medu + traveltime + health
# 0.0187 	 health + Medu + traveltime
# 0.0185 	 Fedu + health + Medu
# 0.0185 	 Fedu + Medu + health
# 0.0184 	 goout + freetime + traveltime + health
# 0.0184 	 goout + freetime + health + traveltime
# 0.0184 	 goout + traveltime + health + freetime
# 0.0184 	 goout + traveltime + freetime + health
# 0.0183 	 studytime + Fedu + freetime + health
# 0.0183 	 studytime + Fedu + health + freetime
# 0.0181 	 famrel + absences + traveltime + freetime
# 0.0181 	 famrel + traveltime + freetime + absences
# 0.0181 	 famrel + traveltime + health + freetime + absences
# 0.0181 	 famrel + absences + freetime + traveltime
# 0.0181 	 famrel + traveltime + absences + freetime
# 0.0181 	 famrel + absences + traveltime + health + freetime
# 0.0181 	 famrel + freetime + traveltime + absences
# 0.0181 	 famrel + freetime + traveltime + health + absences
# 0.0181 	 famrel + traveltime + freetime + health + absences
# 0.0181 	 famrel + absences + freetime + health + traveltime
# 0.0178 	 studytime + age + freetime + traveltime
# 0.0178 	 studytime + age + traveltime + freetime
# 0.0177 	 studytime + famrel + Fedu + traveltime + freetime + Medu
# 0.0177 	 studytime + famrel + Fedu + Medu + traveltime + freetime
# 0.0177 	 studytime + famrel + Fedu + traveltime + Medu + freetime
# 0.0175 	 famrel + Fedu + age + traveltime
# 0.0172 	 studytime + famrel + health
# 0.017 	 studytime + famrel + Fedu + traveltime
# 0.0167 	 goout + famrel + Fedu + health + freetime
# 0.0167 	 goout + famrel + Fedu + freetime + health
# 0.0167 	 age + health
# 0.0167 	 famrel + Fedu + age + traveltime + freetime
# 0.0166 	 famrel + Fedu + traveltime + freetime + Medu
# 0.0166 	 famrel + Fedu + traveltime + Medu + freetime
# 0.0166 	 famrel + Fedu + Medu + traveltime + freetime
# 0.0166 	 goout + health
# 0.0165 	 goout + freetime
# 0.0165 	 freetime + health + Medu
# 0.0165 	 Medu + health + freetime
# 0.0165 	 studytime + famrel
# 0.0165 	 Medu + freetime + health
# 0.0165 	 health + freetime + Medu
# 0.0162 	 studytime + famrel + Fedu + health + freetime
# 0.0162 	 studytime + famrel + Fedu + freetime + health
# 0.0162 	 famrel + Fedu + health + Medu
# 0.0162 	 famrel + Fedu + Medu + health
# 0.0157 	 famrel + age + health
# 0.0157 	 age + traveltime
# 0.0156 	 famrel + Medu + traveltime + health
# 0.0156 	 famrel + health + Medu + traveltime
# 0.0156 	 Fedu + traveltime + health + Medu
# 0.0156 	 famrel + traveltime + health + Medu
# 0.0156 	 famrel + Medu + health + traveltime
# 0.0156 	 Fedu + Medu + traveltime + health
# 0.0153 	 studytime + Fedu + age + traveltime + freetime + health
# 0.0153 	 studytime + Fedu + age + traveltime + health + freetime
# 0.0153 	 Fedu
# 0.0152 	 age
# 0.0152 	 studytime + Medu + freetime + health + traveltime
# 0.0152 	 studytime + freetime + health + Medu + traveltime
# 0.0152 	 studytime + traveltime + health + freetime + Medu
# 0.0152 	 studytime + freetime + traveltime + health + Medu
# 0.0152 	 studytime + Medu + traveltime + health + freetime
# 0.0152 	 studytime + traveltime + freetime + health + Medu
# 0.0151 	 age + freetime + health
# 0.0151 	 age + health + freetime
# 0.0151 	 age + freetime
# 0.015 	 studytime + age + freetime + health + traveltime
# 0.015 	 studytime + age + traveltime + freetime + health
# 0.015 	 studytime + age + freetime + traveltime + health
# 0.015 	 studytime + age + traveltime + health + freetime
# 0.0147 	 studytime + famrel + age + freetime + traveltime
# 0.0147 	 studytime + famrel + age + traveltime + freetime
# 0.0146 	 age + freetime + traveltime
# 0.0146 	 goout + famrel + traveltime + freetime + health
# 0.0146 	 goout + famrel + traveltime + health + freetime
# 0.0146 	 goout + famrel + freetime + health + traveltime
# 0.0146 	 goout + famrel + freetime + traveltime + health
# 0.0146 	 age + traveltime + freetime
# 0.0145 	 goout + famrel + health
# 0.0143 	 Fedu + age + traveltime + health
# 0.0138 	 age + health + traveltime
# 0.0138 	 age + traveltime + health
# 0.0138 	 famrel + Medu + health + freetime
# 0.0138 	 famrel + Medu + freetime + health
# 0.0138 	 famrel + health + freetime + Medu
# 0.0138 	 famrel + freetime + health + Medu
# 0.0136 	 famrel + age + freetime + health
# 0.0136 	 famrel + age + health + freetime
# 0.0133 	 goout + famrel + freetime
# 0.0133 	 studytime + traveltime
# 0.0132 	 Fedu + freetime + health + Medu
# 0.0132 	 Fedu + Medu + health + freetime
# 0.0132 	 Fedu + Medu + freetime + health
# 0.0132 	 Fedu + health + freetime + Medu
# 0.013 	 studytime + Fedu + traveltime + health
# 0.0129 	 famrel + age
# 0.0128 	 studytime + famrel + Fedu + age + traveltime + health + freetime
# 0.0128 	 studytime + famrel + Fedu + age + traveltime + freetime + health
# 0.0127 	 famrel + Fedu
# 0.0126 	 studytime + famrel + age + freetime + health + traveltime
# 0.0126 	 studytime + famrel + age + traveltime + health + freetime
# 0.0126 	 famrel + age + freetime
# 0.0126 	 studytime + famrel + age + freetime + traveltime + health
# 0.0126 	 studytime + famrel + age + traveltime + freetime + health
# 0.0125 	 Medu + freetime + health + traveltime
# 0.0125 	 Medu + traveltime + health + freetime
# 0.0125 	 famrel + Fedu + Medu + traveltime + health
# 0.0125 	 freetime + traveltime + health + Medu
# 0.0125 	 famrel + age + traveltime
# 0.0125 	 freetime + health + Medu + traveltime
# 0.0125 	 famrel + Fedu + traveltime + health + Medu
# 0.0125 	 traveltime + health + freetime + Medu
# 0.0125 	 traveltime + freetime + health + Medu
# 0.0124 	 Fedu + freetime
# 0.0123 	 Fedu + age + traveltime + health + freetime
# 0.0123 	 Fedu + age + traveltime + freetime + health
# 0.0121 	 studytime + Fedu + freetime + traveltime
# 0.0121 	 famrel + Fedu + age + traveltime + health
# 0.0121 	 studytime + Fedu + traveltime + freetime
# 0.0118 	 studytime + famrel + traveltime + health + freetime + Medu
# 0.0118 	 studytime + famrel + freetime + health + Medu + traveltime
# 0.0118 	 studytime + famrel + Medu + freetime + health + traveltime
# 0.0118 	 studytime + famrel + freetime + traveltime + health + Medu
# 0.0118 	 studytime + famrel + Medu + traveltime + health + freetime
# 0.0118 	 studytime + famrel + traveltime + freetime + health + Medu
# 0.0117 	 studytime + freetime
# 0.0116 	 studytime + Fedu + Medu + traveltime + health + freetime
# 0.0116 	 studytime + Fedu + traveltime + freetime + health + Medu
# 0.0116 	 studytime + Fedu + traveltime + health + freetime + Medu
# 0.0115 	 age + freetime + health + traveltime
# 0.0115 	 famrel + age + traveltime + health
# 0.0115 	 age + traveltime + freetime + health
# 0.0115 	 famrel + age + health + traveltime
# 0.0115 	 age + traveltime + health + freetime
# 0.0115 	 age + freetime + traveltime + health
# 0.0112 	 famrel + age + traveltime + freetime
# 0.0112 	 famrel + age + freetime + traveltime
# 0.0109 	 studytime + freetime + health
# 0.0109 	 Fedu + traveltime
# 0.0109 	 studytime + health + freetime
# 0.0104 	 famrel + Fedu + health + freetime + Medu
# 0.0104 	 famrel + Fedu + Medu + health + freetime
# 0.0104 	 famrel + Fedu + freetime + health + Medu
# 0.0104 	 famrel + Fedu + Medu + freetime + health
# 0.0104 	 studytime + health + traveltime
# 0.0104 	 studytime + traveltime + health
# 0.0103 	 studytime + famrel + Fedu + traveltime + health
# 0.00998 	 goout + freetime + health
# 0.00998 	 goout + health + freetime
# 0.00995 	 studytime + famrel + traveltime
# 0.00962 	 famrel + Fedu + age + traveltime + health + freetime
# 0.00962 	 famrel + Fedu + age + traveltime + freetime + health
# 0.00952 	 famrel + Fedu + freetime
# 0.00912 	 Fedu + Medu + traveltime + health + freetime
# 0.00912 	 Fedu + traveltime + freetime + health + Medu
# 0.00912 	 Fedu + traveltime + health + freetime + Medu
# 0.00906 	 famrel + Medu + freetime + health + traveltime
# 0.00906 	 famrel + traveltime + health + freetime + Medu
# 0.00906 	 famrel + freetime + traveltime + health + Medu
# 0.00906 	 famrel + freetime + health + Medu + traveltime
# 0.00906 	 famrel + traveltime + freetime + health + Medu
# 0.00906 	 famrel + Medu + traveltime + health + freetime
# 0.00896 	 studytime + famrel + freetime
# 0.00875 	 studytime + famrel + Fedu + freetime + traveltime
# 0.00875 	 studytime + famrel + Fedu + traveltime + freetime
# 0.00874 	 famrel + age + freetime + health + traveltime
# 0.00874 	 famrel + age + traveltime + freetime + health
# 0.00874 	 famrel + age + freetime + traveltime + health
# 0.00874 	 famrel + age + traveltime + health + freetime
# 0.00866 	 Fedu + health
# 0.00863 	 studytime + famrel + health + freetime
# 0.00863 	 studytime + famrel + freetime + health
# 0.00823 	 studytime + famrel + Fedu + traveltime + freetime + health + Medu
# 0.00823 	 studytime + famrel + Fedu + Medu + traveltime + health + freetime
# 0.00823 	 studytime + famrel + Fedu + traveltime + health + freetime + Medu
# 0.00754 	 studytime + famrel + health + traveltime
# 0.00754 	 studytime + famrel + traveltime + health
# 0.00753 	 famrel + Fedu + traveltime
# 0.0071 	 goout + famrel + health + freetime
# 0.0071 	 goout + famrel + freetime + health
# 0.00699 	 Fedu + traveltime + freetime
# 0.00699 	 Fedu + freetime + traveltime
# 0.00674 	 famrel + Fedu + health
# 0.00564 	 famrel + Fedu + Medu + traveltime + health + freetime
# 0.00564 	 famrel + Fedu + traveltime + freetime + health + Medu
# 0.00564 	 famrel + Fedu + traveltime + health + freetime + Medu
# 0.00551 	 studytime + freetime + traveltime
# 0.00551 	 studytime + traveltime + freetime
# 0.00446 	 Fedu + freetime + health
# 0.00446 	 Fedu + health + freetime
# 0.00402 	 studytime + Fedu + traveltime + health + freetime
# 0.00402 	 studytime + Fedu + traveltime + freetime + health
# 0.00402 	 studytime + Fedu + freetime + traveltime + health
# 0.00346 	 famrel + Fedu + traveltime + freetime
# 0.00346 	 famrel + Fedu + freetime + traveltime
# 0.00321 	 traveltime
# 0.00242 	 Fedu + traveltime + health
# 0.00207 	 famrel + Fedu + health + freetime
# 0.00207 	 famrel + Fedu + freetime + health
# 0.00204 	 studytime + famrel + freetime + traveltime
# 0.00204 	 studytime + famrel + traveltime + freetime
# 0.00173 	 studytime + traveltime + health + freetime
# 0.00173 	 studytime + freetime + traveltime + health
# 0.00173 	 studytime + traveltime + freetime + health
# 0.00173 	 studytime + freetime + health + traveltime
# 0.000939 	 studytime + famrel + Fedu + traveltime + freetime + health
# 0.000939 	 studytime + famrel + Fedu + traveltime + health + freetime
# 0.000939 	 studytime + famrel + Fedu + freetime + traveltime + health
# -0.0093 	 famrel + freetime + health + traveltime
# -0.0093 	 famrel + traveltime + freetime + health
# -0.0093 	 famrel + freetime + traveltime + health
# -0.0093 	 famrel + traveltime + health + freetime
# -0.00707 	 famrel + health + freetime
# -0.00707 	 famrel + freetime + health
# -0.00632 	 famrel + freetime
# -0.00595 	 traveltime + freetime + health
# -0.00595 	 freetime + health + traveltime
# -0.00595 	 freetime + traveltime + health
# -0.00595 	 traveltime + health + freetime
# -0.00586 	 famrel + Fedu + traveltime + health + freetime
# -0.00586 	 famrel + Fedu + traveltime + freetime + health
# -0.00586 	 famrel + Fedu + freetime + traveltime + health
# -0.0048 	 famrel + freetime + traveltime
# -0.0048 	 famrel + traveltime + freetime
# -0.00451 	 freetime + health
# -0.00451 	 health + freetime
# -0.0035 	 famrel + health + traveltime
# -0.0035 	 famrel + traveltime + health
# -0.00325 	 freetime
# -0.00285 	 famrel
# -0.0026 	 Fedu + traveltime + freetime + health
# -0.0026 	 Fedu + freetime + traveltime + health
# -0.0026 	 Fedu + traveltime + health + freetime
# -0.00226 	 famrel + health
# -0.00143 	 studytime + famrel + freetime + health + traveltime
# -0.00143 	 studytime + famrel + traveltime + health + freetime
# -0.00143 	 studytime + famrel + traveltime + freetime + health
# -0.00143 	 studytime + famrel + freetime + traveltime + health
# -0.00121 	 traveltime + freetime
# -0.00121 	 freetime + traveltime
# -0.000581 	 health + traveltime
# -0.000581 	 traveltime + health
# -0.00037 	 famrel + Fedu + traveltime + health
# -0.000213 	 famrel + traveltime
# -0.000154 	 health

# %% [markdown]
# **Комбинация признаков: "failures + absences + Medu + goout + studytime + traveltime" показала наиболее высокий R-squared. Оставим ее.**

# %% [markdown]
# # 5. Анализ номинативных переменных

# %%
# Найдем статистические различия с помощью парного t-теста с использованием поправки Бонферони
for col in df.columns:
    if df[col].dtype == 'object':
        stat_dif_bonf(df, col, 'score')
# Out:
# - Найдены статистически значимые различия для переменной "address": R, U.
# - Найдены статистически значимые различия для переменной "Mjob": health, at_home.
# - Найдены статистически значимые различия для переменной "Fjob": teacher, other.
# - Найдены статистически значимые различия для переменной "Fjob": teacher, services.
# - Найдены статистически значимые различия для переменной "schoolsup": yes, no.

# %% [markdown]
# **В проведенном анализе использовалась поправка Бонферони на множественные сравнения.
# Её довольно часто критикуют в связи с излишней консервативностью.**

# %% [markdown]
# ## Используем критерий Тьюки

# %%
columns_in = []

for col in df.columns:
    if df[col].dtype == 'object':
        columns_in.append(col)

stat_dif_tukey(df, columns_in, 'score', 10, 0.05)
# Out:
#       group1   group2  meandiff   p-adj    lower    upper  reject    feature
# 1          R        U    4.9038  0.0290   0.5066   9.3011    True    address
# 1    at_home   health   10.6602  0.0405   0.2912  21.0293    True       Mjob
# 9      other  teacher   10.3213  0.0212   1.0212  19.6214    True       Fjob
# 10  services  teacher   10.7877  0.0251   0.8816  20.6938    True       Fjob
# 1         no      yes  -10.1503  0.0001 -15.2693  -5.0313    True  schoolsup
# Найдены статистически значимые различия в:
# Fjob         2
# address      1
# Mjob         1
# schoolsup    1
# Name: feature, dtype: int64

# %% [markdown]
# ### Проверка с использованием критрия Тьюки показала аналогичные результаты.

# %% [markdown]
# ## Рассмотрим более детально переменные Fjob, address, Mjob, schoolsup:

# %% [markdown]
# ### Переменная 'Fjob':

# %%
get_boxplot(df, 'Fjob', 'score')

# %% [markdown]
# Различия в группах:
# - **teacher**	и **other**
# - **teacher** и **services**
#
# **Можно сделать вывод, что ученики, чьи отцы работают учителями, показывают более высокие результаты в учебе, чем те школьники, чьи отцы, работают на госслужбе или имеют другую, не включённую в перечень, профессию.**

# %% [markdown]
# ### Переменная 'Mjob':

# %%
get_boxplot(df, 'Mjob', 'score')

# %% [markdown]
# Различия в группах:
# - **health** и **at_home**
#
# **Можно сделать вывод, что ученики, чья мать работает в сфере здравоохранения, в среднем учатся лучше, чем ученики, чья мать не работает.**

# %% [markdown]
# ### Переменная 'address':

# %%
get_boxplot(df, 'address', 'score')

# %% [markdown]
# **Можно сделать вывод, что ученики, проживающие в городе в среднем имеют более высокую успеваемость, чем ученики, проживающие за городом.**

# %% [markdown]
# ### Переменная 'schoolsup':

# %%
get_boxplot(df, 'schoolsup', 'score')

# %% [markdown]
# **Можно сделать вывод, что ученики без дополнительной образовательной поддержки в среднем сдают экзамены лучше, чем с ней.
# Это может свидетельствовать о том, что поддержку оказывают более слабым ученикам.**

# %% [markdown]
# # 6. Выводы

# %% [markdown]
# - Данные достаточно чистые, выбросы найдены в столбцах "Fedu" и "score".
# - Наблюдается приемлемое количество пропусков (не более 11,4%), которые можно заменить наиболее частотными значениями.
# - Неинформативный столбец "granular" повторяет признак "studytime" с обратной корреляцией.

# %% [markdown]
# ### Зависимости, которые будут использованы в модели
#
# **Числовые переменные:**
#
# - С единичным увеличением "failures" целевой параметр "score" изменяется на -0.272112 (при неизменных остальных перменных).
# Ученики, имеющие больше внеучебных неудач, учатся хуже.
# - С единичным увеличением "Medu" целевой параметр возрастает на 0.180558.
# Чем более хорошее образование имеет мать ребенка, тем лучше его результаты в учебе.
# - С единичным увеличением "absences" целевой параметр изменяется на -0.172132.
# Чем больше ученики пропускают уроки, тем хуже они учатся.
# - С единичным увеличением "goout" целевой параметр изменяется на -0.160280.
# Чем больше времени ученики проводят с друзьями, тем менее эффективно они учатся.
# - С единичным увеличением "studytime" целевой параметр возрастает на 0.149390.
# Чем больше ученики уделяют внимание урокам, тем лучше они учатся.
# - С единичным увеличением "traveltime" целевой параметр изменяется на -0.081853.
# Ученики, живущие дальше от школы, менее успешны в учёбе.
#
# **Номинативные переменные:**
#
# - Ученики, чьи отцы работают учителями, показывают более высокие результаты в учебе чем те школьники, чьи отцы работают на госслужбе или имеют другую, не включённую в перечень, профессию.
# - Ученики, чьи матери работают в сфере здравоохранения, в среднем учатся лучше, чем ученики, чья мать не работает.
# - Ученики, проживающие в городе, в среднем имеют более высокую успеваемость, чем ученики, проживающие за городом.
# - Ученики, которые не пользуются дополнительной образовательной поддержкой в среднем имеют более высокие результаты в учебе, чем те ученики, которым оказывают такую поддержку. Это может свидетельствовать о том, что поддержку предоставляют более слабым ученикам.

# %% [markdown]
# ### Парамерты, которые предлагается использовать для построения модели:
# - числовые переменные: **failures, absences, Medu, traveltime, goout, studytime**
# - номинативные переменные: **Fjob, address, Mjob, schoolsup**

# %%
# Датасет для модели:
model_df = df.loc[:, ['failures', 'absences', 'Medu', 'traveltime','goout', 'studytime', 
                      'Fjob', 'address', 'Mjob', 'schoolsup', 'score']]
model_df.head()
# Out:
#    failures  absences  Medu  traveltime  goout  studytime     Fjob address  \
# 0       0.0  1.945910   4.0         2.0    4.0        2.0  teacher       U
# 1       0.0  1.609438   1.0         1.0    3.0        2.0    other       U
# 2       3.0  2.397895   1.0         1.0    2.0        2.0    other       U
# 3       0.0  1.098612   4.0         1.0    2.0        3.0      NaN       U
# 4       0.0  1.609438   3.0         1.0    2.0        2.0    other       U
#
#       Mjob schoolsup  score
# 0  at_home       yes   30.0
# 1  at_home        no   30.0
# 2  at_home       yes   50.0
# 3   health        no   75.0
# 4    other        no   50.0
